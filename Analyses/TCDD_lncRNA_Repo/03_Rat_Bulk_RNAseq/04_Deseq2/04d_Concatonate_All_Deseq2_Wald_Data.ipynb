# %% [markdown]
# # Concatonate All Deseq2 Data with Karri RefGenome Metadata

# %% [markdown]
# ## <br> 1. Import Required Packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## <br> 2. Import Deseq2 Data and All Other Metadata

# %%
pDREs_Master = pd.read_csv('../../99_rn7_DREs/02_CleanUp_DRE_BED_File/DRE_Counts_by_Gene.txt', 
                            delimiter = '\t')

pDREs_Master = pDREs_Master.dropna()

pDREs_Master = pDREs_Master.rename(columns={'gene_id': 'Gene', 'count': 'pDRE'})

pDREs_Master.head(5)
# Out:
#        Gene  pDRE
# 1  lnc10851   273
# 2     Tenm3   249
# 3   Auts2l1   193
# 4    Camta1   179
# 5     Cdh13   141

# %%
AHR_Master = pd.read_csv('../../99_rn7_AHR_Enrichment/02_CleanUp_BED_File/rn7_AHR_Binding_Counts.txt', 
                            delimiter = '\t')

AHR_Master = AHR_Master.rename(columns={'gene_id': 'Gene', 'count': 'AHR'})

AHR_Master.head(5)
# Out:
#        Gene   AHR
# 0       NaN  3089
# 1  lnc10851   144
# 2  lnc16454    41
# 3   lnc4726    23
# 4     Prkce    19

# %%
# Define column names based on GTF format
gtf_columns = [
    "chrom", "source", "feature", "start", "end", "score", "strand", "frame", "space1", "space2", "attribute"
]

Annotations_Master = pd.read_csv('../../00_Karri_et_al_GTF/Karri_Annotations_Restructured_rn7_for_Gene_Expression.gtf', 
                                delimiter = '\t',
                                names=gtf_columns)  # Assign column names)

# Drop unwanted columns
Annotations_Master = Annotations_Master.drop(columns=["space1", "space2"])

Annotations_Master
# Out:
#                               chrom      source feature      start        end  \
# 0                              chr5    liftover    exon   15038462   15039082
# 1                              chr5    liftover    exon   14766774   14767820
# 2                             chr13    liftover    exon  103001424  103005924
# 3                             chr10    liftover    exon   79676628   79677257
# 4                             chr10    liftover    exon   79677716   79678362
# ...                             ...         ...     ...        ...        ...
# 1182956  chrY_NW_023637722v1_random  ncbiRefSeq    exon     293338     293506
# 1182957  chrY_NW_023637722v1_random  ncbiRefSeq    exon     300877     300988
# 1182958  chrY_NW_023637722v1_random  ncbiRefSeq    exon     317993     319851
# 1182959  chrY_NW_023637722v1_random  ncbiRefSeq    exon     320383     320541
# 1182960  chrY_NW_023637722v1_random  ncbiRefSeq    exon     321212     321506
#
#          score strand frame                                          attribute
# 0         1000      +     .  Mouse_ID "0"; gene_id "lnc1"; transcript_type ...
# 1         1000      +     .  Mouse_ID "1"; gene_id "lnc10"; transcript_type...
# 2         1000      +     .  Mouse_ID "3"; gene_id "lnc1000"; transcript_ty...
# 3         1000      -     .  Mouse_ID "4"; gene_id "lnc10000"; transcript_t...
# 4         1000      -     .  Mouse_ID "5"; gene_id "lnc10001"; transcript_t...
# ...        ...    ...   ...                                                ...
# 1182956   1000      +     .  Rat_ID "1141644"; gene_id "LOC103694730"; tran...
# 1182957   1000      +     .  Rat_ID "1141645"; gene_id "LOC103694730"; tran...
# 1182958   1000      -     .  Rat_ID "1141646"; gene_id "LOC120099645"; tran...
# 1182959   1000      -     .  Rat_ID "1141647"; gene_id "LOC120099645"; tran...
# 1182960   1000      -     .  Rat_ID "1141648"; gene_id "LOC120099645"; tran...
#
# [1182961 rows x 9 columns]

# %%
# Define a function to parse attributes and extract key-value pairs
def parse_attributes(attribute_string):
    attr_dict = {}
    if pd.notnull(attribute_string):  # Check if the string is not NaN
        attributes = attribute_string.split(';')
        for attribute in attributes:
            if attribute.strip():  # Ensure it's not an empty string
                key, value = attribute.strip().split(' ', 1)
                attr_dict[key] = value.strip('"')  # Strip quotes from value
    return attr_dict

# Apply the function to extract the information into a DataFrame
attributes_df = Annotations_Master['attribute'].apply(parse_attributes).apply(pd.Series)

attributes_df
# Out:
#         Mouse_ID       gene_id   transcript_type   Rat_ID
# 0              0          lnc1            lncRNA      NaN
# 1              1         lnc10            lncRNA      NaN
# 2              3       lnc1000            lncRNA      NaN
# 3              4      lnc10000            lncRNA      NaN
# 4              5      lnc10001            lncRNA      NaN
# ...          ...           ...               ...      ...
# 1182956      NaN  LOC103694730  predicted_lncRNA  1141644
# 1182957      NaN  LOC103694730  predicted_lncRNA  1141645
# 1182958      NaN  LOC120099645  predicted_lncRNA  1141646
# 1182959      NaN  LOC120099645  predicted_lncRNA  1141647
# 1182960      NaN  LOC120099645  predicted_lncRNA  1141648
#
# [1182961 rows x 4 columns]

# %%
# Concatenate the two DataFrames side by side
merged_combined = pd.concat([Annotations_Master, attributes_df], axis=1)
merged_combined
# Out:
#                               chrom      source feature      start        end  \
# 0                              chr5    liftover    exon   15038462   15039082
# 1                              chr5    liftover    exon   14766774   14767820
# 2                             chr13    liftover    exon  103001424  103005924
# 3                             chr10    liftover    exon   79676628   79677257
# 4                             chr10    liftover    exon   79677716   79678362
# ...                             ...         ...     ...        ...        ...
# 1182956  chrY_NW_023637722v1_random  ncbiRefSeq    exon     293338     293506
# 1182957  chrY_NW_023637722v1_random  ncbiRefSeq    exon     300877     300988
# 1182958  chrY_NW_023637722v1_random  ncbiRefSeq    exon     317993     319851
# 1182959  chrY_NW_023637722v1_random  ncbiRefSeq    exon     320383     320541
# 1182960  chrY_NW_023637722v1_random  ncbiRefSeq    exon     321212     321506
#
#          score strand frame  \
# 0         1000      +     .
# 1         1000      +     .
# 2         1000      +     .
# 3         1000      -     .
# 4         1000      -     .
# ...        ...    ...   ...
# 1182956   1000      +     .
# 1182957   1000      +     .
# 1182958   1000      -     .
# 1182959   1000      -     .
# 1182960   1000      -     .
#
#                                                  attribute Mouse_ID  \
# 0        Mouse_ID "0"; gene_id "lnc1"; transcript_type ...        0
# 1        Mouse_ID "1"; gene_id "lnc10"; transcript_type...        1
# 2        Mouse_ID "3"; gene_id "lnc1000"; transcript_ty...        3
# 3        Mouse_ID "4"; gene_id "lnc10000"; transcript_t...        4
# 4        Mouse_ID "5"; gene_id "lnc10001"; transcript_t...        5
# ...                                                    ...      ...
# 1182956  Rat_ID "1141644"; gene_id "LOC103694730"; tran...      NaN
# 1182957  Rat_ID "1141645"; gene_id "LOC103694730"; tran...      NaN
# 1182958  Rat_ID "1141646"; gene_id "LOC120099645"; tran...      NaN
# 1182959  Rat_ID "1141647"; gene_id "LOC120099645"; tran...      NaN
# 1182960  Rat_ID "1141648"; gene_id "LOC120099645"; tran...      NaN
#
#               gene_id   transcript_type   Rat_ID
# 0                lnc1            lncRNA      NaN
# 1               lnc10            lncRNA      NaN
# 2             lnc1000            lncRNA      NaN
# 3            lnc10000            lncRNA      NaN
# 4            lnc10001            lncRNA      NaN
# ...               ...               ...      ...
# 1182956  LOC103694730  predicted_lncRNA  1141644
# 1182957  LOC103694730  predicted_lncRNA  1141645
# 1182958  LOC120099645  predicted_lncRNA  1141646
# 1182959  LOC120099645  predicted_lncRNA  1141647
# 1182960  LOC120099645  predicted_lncRNA  1141648
#
# [1182961 rows x 13 columns]

# %%
merged_combined.columns
# Out:
# Index(['chrom', 'source', 'feature', 'start', 'end', 'score', 'strand',
#        'frame', 'attribute', 'Mouse_ID', 'gene_id', 'transcript_type',
#        'Rat_ID'],
#       dtype='object')

# %%
merged_combined2 = merged_combined[[]]

# %%
directory = './Deseq2_Results/'

Deseq2_0_01_v_0 = pd.read_csv(directory + '0.01_vs_0.txt', delimiter = '\t').reset_index()
Deseq2_0_03_v_0 = pd.read_csv(directory + '0.03_vs_0.txt', delimiter = '\t').reset_index()
Deseq2_0_1_v_0 = pd.read_csv(directory + '0.1_vs_0.txt', delimiter = '\t').reset_index()
Deseq2_0_3_v_0 = pd.read_csv(directory + '0.3_vs_0.txt', delimiter = '\t').reset_index()
Deseq2_1_v_0 = pd.read_csv(directory + '1_vs_0.txt', delimiter = '\t').reset_index()
Deseq2_3_v_0 = pd.read_csv(directory + '3_vs_0.txt', delimiter = '\t').reset_index()
Deseq2_10_v_0 = pd.read_csv(directory + '10_vs_0.txt', delimiter = '\t').reset_index()

# %%
Deseq2_0_01_v_0['Dose'] = '0.01'
Deseq2_0_03_v_0['Dose'] = '0.03'
Deseq2_0_1_v_0['Dose'] = '0.1'
Deseq2_0_3_v_0['Dose'] = '0.3'
Deseq2_1_v_0['Dose'] = '1'
Deseq2_3_v_0['Dose'] = '3'
Deseq2_10_v_0['Dose'] = '10'

# %%
Deseq2_10_v_0.head(5)
# Out:
#       index  baseMean  log2FoldChange     lfcSE      stat    pvalue  padj Dose
# 0   lnc1000  1.021823        1.224408  1.866052  0.656149  0.511728   NaN   10
# 1  lnc10000  0.046372       -1.398125  6.005823 -0.232795  0.815921   NaN   10
# 2  lnc10001  0.146825        0.000000  6.005823  0.000000  1.000000   NaN   10
# 3  lnc10003  0.177874       -1.398177  6.005823 -0.232804  0.815914   NaN   10
# 4  lnc10004  0.740087        3.883753  3.422047  1.134921  0.256409   NaN   10

# %% [markdown]
# ## <br> 3. Concat All Data Into One Dataframe

# %%
Deseq2_Master = pd.concat([Deseq2_0_01_v_0,
                          Deseq2_0_03_v_0,
                          Deseq2_0_1_v_0,
                          Deseq2_0_3_v_0,
                          Deseq2_1_v_0,
                          Deseq2_3_v_0,
                          Deseq2_10_v_0],
                          ignore_index=True)

# %%
Deseq2_Master = Deseq2_Master.rename(columns={'index': 'Gene'})
Deseq2_Master['FoldChange'] = pow(2, Deseq2_Master['log2FoldChange'])

Deseq2_Master.head(5)
# Out:
#        Gene  baseMean  log2FoldChange     lfcSE      stat    pvalue  padj  \
# 0   lnc1000  1.021823       -0.020692  1.991121 -0.010392  0.991708   NaN
# 1  lnc10000  0.046372       -0.929325  6.005823 -0.154737  0.877028   NaN
# 2  lnc10001  0.146825        0.000000  6.005823  0.000000  1.000000   NaN
# 3  lnc10003  0.177874        0.032402  6.005823  0.005395  0.995695   NaN
# 4  lnc10004  0.740087        0.000000  3.592880  0.000000  1.000000   NaN
#
#    Dose  FoldChange
# 0  0.01    0.985760
# 1  0.01    0.525104
# 2  0.01    1.000000
# 3  0.01    1.022714
# 4  0.01    1.000000

# %%
merged_combined.columns
# Out:
# Index(['chrom', 'source', 'feature', 'start', 'end', 'score', 'strand',
#        'frame', 'attribute', 'Mouse_ID', 'gene_id', 'transcript_type',
#        'Rat_ID'],
#       dtype='object')

# %%
merged_combined2 = merged_combined[['chrom', 'start', 'end','frame', 'score','strand', 'source', 'gene_id', 'transcript_type', 'Mouse_ID', 'Rat_ID']]

# %%
# Merge Deseq2_Master with all metadata tables
Deseq2_Master2 = pd.merge(Deseq2_Master, merged_combined2, left_on='Gene', right_on='gene_id', how='left').fillna("NA")

Deseq2_Master2
# Out:
#                  Gene   baseMean  log2FoldChange     lfcSE      stat  \
# 0             lnc1000   1.021823       -0.020692  1.991121 -0.010392
# 1            lnc10000   0.046372       -0.929325  6.005823 -0.154737
# 2            lnc10001   0.146825        0.000000  6.005823  0.000000
# 3            lnc10003   0.177874        0.032402  6.005823  0.005395
# 4            lnc10004   0.740087        0.000000  3.592880  0.000000
# ...               ...        ...             ...       ...       ...
# 7722262  LOC103694537  17.353741        0.172073  0.466195  0.369101
# 7722263  LOC103694537  17.353741        0.172073  0.466195  0.369101
# 7722264  LOC120099632   0.048942        0.000000  6.005823  0.000000
# 7722265  LOC120099632   0.048942        0.000000  6.005823  0.000000
# 7722266         Etaa1  12.976070        0.108092  0.443788  0.243566
#
#            pvalue      padj  Dose  FoldChange                       chrom  \
# 0        0.991708        NA  0.01    0.985760                       chr13
# 1        0.877028        NA  0.01    0.525104                       chr10
# 2             1.0        NA  0.01    1.000000                       chr10
# 3        0.995695        NA  0.01    1.022714                       chr10
# 4             1.0        NA  0.01    1.000000                       chr10
# ...           ...       ...   ...         ...                         ...
# 7722262  0.712052  0.850128    10    1.126676  chrY_NW_023637718v1_random
# 7722263  0.712052  0.850128    10    1.126676  chrY_NW_023637718v1_random
# 7722264       1.0        NA    10    1.000000  chrY_NW_023637718v1_random
# 7722265       1.0        NA    10    1.000000  chrY_NW_023637718v1_random
# 7722266  0.807567  0.907902    10    1.077802  chrY_NW_023637721v1_random
#
#              start        end frame  score strand      source       gene_id  \
# 0        103001424  103005924     .   1000      +    liftover       lnc1000
# 1         79676628   79677257     .   1000      -    liftover      lnc10000
# 2         79677716   79678362     .   1000      -    liftover      lnc10001
# 3         79954144   79959715     .   1000      -    liftover      lnc10003
# 4         80089972   80105010     .   1000      +    liftover      lnc10004
# ...            ...        ...   ...    ...    ...         ...           ...
# 7722262     142349     142592     .   1000      -  ncbiRefSeq  LOC103694537
# 7722263     142792     143078     .   1000      -  ncbiRefSeq  LOC103694537
# 7722264     187188     191437     .   1000      -  ncbiRefSeq  LOC120099632
# 7722265     191439     192518     .   1000      -  ncbiRefSeq  LOC120099632
# 7722266      82207      85543     .   1000      -  ncbiRefSeq         Etaa1
#
#         transcript_type Mouse_ID   Rat_ID
# 0                lncRNA        3       NA
# 1                lncRNA        4       NA
# 2                lncRNA        5       NA
# 3                lncRNA        7       NA
# 4                lncRNA        8       NA
# ...                 ...      ...      ...
# 7722262  predicted_mRNA       NA  1141569
# 7722263  predicted_mRNA       NA  1141570
# 7722264  predicted_mRNA       NA  1141571
# 7722265  predicted_mRNA       NA  1141572
# 7722266  predicted_mRNA       NA  1141628
#
# [7722267 rows x 20 columns]

# %%
# Drop the 'Gene' column
#Deseq2_Master2 = Deseq2_Master2.drop(columns=['Gene'])

#Deseq2_Master2 = Deseq2_Master2.rename(columns={'gene_name': 'Gene'})
Deseq2_Master2 = Deseq2_Master2.rename(columns={'FoldChange': 'Fold-Change'})
Deseq2_Master2 = Deseq2_Master2.rename(columns={'log2FoldChange': 'Log2FC'})

Deseq2_Master2 = pd.merge(Deseq2_Master2, pDREs_Master, left_on='Gene', right_on='Gene', how='left').fillna(0)
Deseq2_Master2 = pd.merge(Deseq2_Master2, AHR_Master, left_on='Gene', right_on='Gene', how='left').fillna(0)

Deseq2_Master2[['pDRE', 'AHR']] = Deseq2_Master2[['pDRE', 'AHR']].astype(int)

Deseq2_Master_Working = Deseq2_Master2[['Gene', 'Dose', 'pDRE', 'AHR', 'transcript_type',  'baseMean',
                                      'Log2FC', 'Fold-Change', 'lfcSE', 'stat', 'pvalue', 'padj',
                                       'chrom', 'start', 'end', 'frame', 'score','strand', 'source',
                                        'gene_id', 'Mouse_ID', 'Rat_ID']].drop_duplicates(keep='first')

Deseq2_Master_Working
# Out:
#                  Gene  Dose  pDRE  AHR transcript_type   baseMean    Log2FC  \
# 0             lnc1000  0.01     0    1          lncRNA   1.021823 -0.020692
# 1            lnc10000  0.01     1    0          lncRNA   0.046372 -0.929325
# 2            lnc10001  0.01     0    0          lncRNA   0.146825  0.000000
# 3            lnc10003  0.01     2    0          lncRNA   0.177874  0.032402
# 4            lnc10004  0.01     7    1          lncRNA   0.740087  0.000000
# ...               ...   ...   ...  ...             ...        ...       ...
# 7722262  LOC103694537    10     0    0  predicted_mRNA  17.353741  0.172073
# 7722263  LOC103694537    10     0    0  predicted_mRNA  17.353741  0.172073
# 7722264  LOC120099632    10     0    0  predicted_mRNA   0.048942  0.000000
# 7722265  LOC120099632    10     0    0  predicted_mRNA   0.048942  0.000000
# 7722266         Etaa1    10     0    0  predicted_mRNA  12.976070  0.108092
#
#          Fold-Change     lfcSE      stat  ...                       chrom  \
# 0           0.985760  1.991121 -0.010392  ...                       chr13
# 1           0.525104  6.005823 -0.154737  ...                       chr10
# 2           1.000000  6.005823  0.000000  ...                       chr10
# 3           1.022714  6.005823  0.005395  ...                       chr10
# 4           1.000000  3.592880  0.000000  ...                       chr10
# ...              ...       ...       ...  ...                         ...
# 7722262     1.126676  0.466195  0.369101  ...  chrY_NW_023637718v1_random
# 7722263     1.126676  0.466195  0.369101  ...  chrY_NW_023637718v1_random
# 7722264     1.000000  6.005823  0.000000  ...  chrY_NW_023637718v1_random
# 7722265     1.000000  6.005823  0.000000  ...  chrY_NW_023637718v1_random
# 7722266     1.077802  0.443788  0.243566  ...  chrY_NW_023637721v1_random
#
#              start        end  frame  score strand      source       gene_id  \
# 0        103001424  103005924      .   1000      +    liftover       lnc1000
# 1         79676628   79677257      .   1000      -    liftover      lnc10000
# 2         79677716   79678362      .   1000      -    liftover      lnc10001
# 3         79954144   79959715      .   1000      -    liftover      lnc10003
# 4         80089972   80105010      .   1000      +    liftover      lnc10004
# ...            ...        ...    ...    ...    ...         ...           ...
# 7722262     142349     142592      .   1000      -  ncbiRefSeq  LOC103694537
# 7722263     142792     143078      .   1000      -  ncbiRefSeq  LOC103694537
# 7722264     187188     191437      .   1000      -  ncbiRefSeq  LOC120099632
# 7722265     191439     192518      .   1000      -  ncbiRefSeq  LOC120099632
# 7722266      82207      85543      .   1000      -  ncbiRefSeq         Etaa1
#
#         Mouse_ID   Rat_ID
# 0              3       NA
# 1              4       NA
# 2              5       NA
# 3              7       NA
# 4              8       NA
# ...          ...      ...
# 7722262       NA  1141569
# 7722263       NA  1141570
# 7722264       NA  1141571
# 7722265       NA  1141572
# 7722266       NA  1141628
#
# [7722267 rows x 22 columns]

# %%
Deseq2_Master_Working2 = Deseq2_Master_Working[['Gene', 'Dose', 'pDRE', 'AHR', 'transcript_type',  'baseMean',
                                      'Log2FC', 'Fold-Change', 'lfcSE', 'stat', 'pvalue', 'padj','source' ]].drop_duplicates(keep='first')
Deseq2_Master_Working2
# Out:
#                  Gene  Dose  pDRE  AHR   transcript_type    baseMean  \
# 0             lnc1000  0.01     0    1            lncRNA    1.021823
# 1            lnc10000  0.01     1    0            lncRNA    0.046372
# 2            lnc10001  0.01     0    0            lncRNA    0.146825
# 3            lnc10003  0.01     2    0            lncRNA    0.177874
# 4            lnc10004  0.01     7    1            lncRNA    0.740087
# ...               ...   ...   ...  ...               ...         ...
# 7722234  LOC120099597    10     1    0  predicted_lncRNA    0.092333
# 7722237          Dkc1    10     0    2              mRNA  277.395024
# 7722252  LOC103694537    10     0    0    predicted_mRNA   17.353741
# 7722264  LOC120099632    10     0    0    predicted_mRNA    0.048942
# 7722266         Etaa1    10     0    0    predicted_mRNA   12.976070
#
#            Log2FC  Fold-Change     lfcSE      stat    pvalue      padj  \
# 0       -0.020692     0.985760  1.991121 -0.010392  0.991708        NA
# 1       -0.929325     0.525104  6.005823 -0.154737  0.877028        NA
# 2        0.000000     1.000000  6.005823  0.000000       1.0        NA
# 3        0.032402     1.022714  6.005823  0.005395  0.995695        NA
# 4        0.000000     1.000000  3.592880  0.000000       1.0        NA
# ...           ...          ...       ...       ...       ...       ...
# 7722234 -1.398142     0.379417  6.005823 -0.232798  0.815918        NA
# 7722237  1.901728     3.736606  0.248099  7.665213       0.0       0.0
# 7722252  0.172073     1.126676  0.466195  0.369101  0.712052  0.850128
# 7722264  0.000000     1.000000  6.005823  0.000000       1.0        NA
# 7722266  0.108092     1.077802  0.443788  0.243566  0.807567  0.907902
#
#              source
# 0          liftover
# 1          liftover
# 2          liftover
# 3          liftover
# 4          liftover
# ...             ...
# 7722234  ncbiRefSeq
# 7722237  ncbiRefSeq
# 7722252  ncbiRefSeq
# 7722264  ncbiRefSeq
# 7722266  ncbiRefSeq
#
# [402199 rows x 13 columns]

# %%
Deseq2_Master_Working2.to_csv('./RDDR_Deseq2_Master_Wald_Rat_with_Mouse_MGI.txt', sep='\t')
