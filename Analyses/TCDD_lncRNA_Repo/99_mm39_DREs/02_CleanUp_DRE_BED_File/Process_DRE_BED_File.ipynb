# %% [markdown]
# # Visualization of mm39 DREs (histograms)

# %% [markdown]
# ### 1. Import packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 2. Import DRE genomic coordinates

# %%
# Define the file path
file_path = "../01_Intersect_DRE_and_GTF/DREs_in_lncRNAs_MSS_0.861.bed"

# Read the file into a DataFrame
df = pd.read_csv(file_path, sep='\t', header=0, index_col=None)

# Display the DataFrame
df
# Out:
#       Chromosome  DRE_Start   DRE_End  DRE_ID DRE_Strand   DRE_MSS  \
# 0           chr1    3493457   3493476       1          +  0.870102
# 1           chr1    4240913   4240932       2          -  0.877970
# 2           chr1    4427961   4427980       3          +  0.872268
# 3           chr1    4476897   4476916       4          -  0.901051
# 4           chr1    4491129   4491148       5          -  0.867355
# ...          ...        ...       ...     ...        ...       ...
# 60905       chrY   90644962  90644981   44321          +  0.871128
# 60906       chrY   90644966  90644985   44322          +  0.861266
# 60907       chrY   90776986  90777005   44323          -  0.869231
# 60908       chrY   90782870  90782889   44324          +  0.887751
# 60909       chrY   90804927  90804946   44325          -  0.881386
#
#       GTF_Chromosome  Gene_Start  Gene_End Gene_Strand Gene_ORIG_Start  \
# 0               chr1     3284705   3751721           -         3741721
# 1               chr1     4190089   4489464           -         4479464
# 2               chr1     4190089   4489464           -         4479464
# 3               chr1     4190089   4489464           -         4479464
# 4                  .          -1        -1           .               .
# ...              ...         ...       ...         ...             ...
# 60905              .          -1        -1           .               .
# 60906              .          -1        -1           .               .
# 60907              .          -1        -1           .               .
# 60908              .          -1        -1           .               .
# 60909           chrY    90786711  90827734           +        90796711
#
#                                                                                                   Metadata
# 0      gene_id"Xkr4";transcript_id"Xkr4";gene_name"Xkr4";gene_name2"NM_001011874(Non-Dups)";gene_biotyp...
# 1      gene_id"Rp1";transcript_id"Rp1";gene_name"Rp1";gene_name2"NM_001195662#NM_001370921#NM_011283(No...
# 2      gene_id"Rp1";transcript_id"Rp1";gene_name"Rp1";gene_name2"NM_001195662#NM_001370921#NM_011283(No...
# 3      gene_id"Rp1";transcript_id"Rp1";gene_name"Rp1";gene_name2"NM_001195662#NM_001370921#NM_011283(No...
# 4                                                                                                        .
# ...                                                                                                    ...
# 60905                                                                                                    .
# 60906                                                                                                    .
# 60907                                                                                                    .
# 60908                                                                                                    .
# 60909  gene_id"Erdr1";transcript_id"Erdr1";gene_name"Erdr1";gene_name2"NM_133362#NR_137282(Non-Dups)";g...
#
# [60910 rows x 12 columns]

# %%
# Extract the "gene_id" information and create a new column
df['gene_id'] = df['Metadata'].str.extract(r'gene_id"([^"]+)"', expand=False)
# Fill rows without "gene_id" with NA
df['gene_id'].fillna('NA', inplace=True)

# Extract the "transcript_id" information and create a new column
df['transcript_id'] = df['Metadata'].str.extract(r'transcript_id"([^"]+)"', expand=False)
# Fill rows without "transcript_id" with NA
df['transcript_id'].fillna('NA', inplace=True)

# Extract the "gene_name" information and create a new column
df['gene_name'] = df['Metadata'].str.extract(r'gene_name"([^"]+)"', expand=False)
# Fill rows without "gene_name" with NA
df['gene_name'].fillna('NA', inplace=True)

# Extract the "gene_name2" information and create a new column
df['gene_name2'] = df['Metadata'].str.extract(r'gene_name2"([^"]+)"', expand=False)
# Fill rows without "gene_name2" with NA
df['gene_name2'].fillna('NA', inplace=True)

# Extract the "gene_biotype" information and create a new column
df['gene_biotype'] = df['Metadata'].str.extract(r'gene_biotype"([^"]+)"', expand=False)
# Fill rows without "gene_biotype" with NA
df['gene_biotype'].fillna('NA', inplace=True)

# Extract the "NR_annotation" information and create a new column
df['NR_annotation'] = df['Metadata'].str.extract(r'NR_annotation"([^"]+)"', expand=False)
# Fill rows without "NR_annotation" with NA
df['NR_annotation'].fillna('NA', inplace=True)

# Remove the "Metadata" column
df.drop(columns=['Metadata'], inplace=True)

# Drop duplicate rows and keep the first occurrence
df = df.drop_duplicates(keep='first')

# Display the DataFrame
df
# Out:
# /tmp/local/51388227/ipykernel_3027031/1887011354.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gene_id'].fillna('NA', inplace=True)
# /tmp/local/51388227/ipykernel_3027031/1887011354.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['transcript_id'].fillna('NA', inplace=True)
# /tmp/local/51388227/ipykernel_3027031/1887011354.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gene_name'].fillna('NA', inplace=True)
# /tmp/local/51388227/ipykernel_3027031/1887011354.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gene_name2'].fillna('NA', inplace=True)
# /tmp/local/51388227/ipykernel_3027031/1887011354.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gene_biotype'].fillna('NA', inplace=True)
# /tmp/local/51388227/ipykernel_3027031/1887011354.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NR_annotation'].fillna('NA', inplace=True)
#       Chromosome  DRE_Start   DRE_End  DRE_ID DRE_Strand   DRE_MSS  \
# 0           chr1    3493457   3493476       1          +  0.870102
# 1           chr1    4240913   4240932       2          -  0.877970
# 2           chr1    4427961   4427980       3          +  0.872268
# 3           chr1    4476897   4476916       4          -  0.901051
# 4           chr1    4491129   4491148       5          -  0.867355
# ...          ...        ...       ...     ...        ...       ...
# 60905       chrY   90644962  90644981   44321          +  0.871128
# 60906       chrY   90644966  90644985   44322          +  0.861266
# 60907       chrY   90776986  90777005   44323          -  0.869231
# 60908       chrY   90782870  90782889   44324          +  0.887751
# 60909       chrY   90804927  90804946   44325          -  0.881386
#
#       GTF_Chromosome  Gene_Start  Gene_End Gene_Strand Gene_ORIG_Start  \
# 0               chr1     3284705   3751721           -         3741721
# 1               chr1     4190089   4489464           -         4479464
# 2               chr1     4190089   4489464           -         4479464
# 3               chr1     4190089   4489464           -         4479464
# 4                  .          -1        -1           .               .
# ...              ...         ...       ...         ...             ...
# 60905              .          -1        -1           .               .
# 60906              .          -1        -1           .               .
# 60907              .          -1        -1           .               .
# 60908              .          -1        -1           .               .
# 60909           chrY    90786711  90827734           +        90796711
#
#       gene_id transcript_id gene_name  \
# 0        Xkr4          Xkr4      Xkr4
# 1         Rp1           Rp1       Rp1
# 2         Rp1           Rp1       Rp1
# 3         Rp1           Rp1       Rp1
# 4          NA            NA        NA
# ...       ...           ...       ...
# 60905      NA            NA        NA
# 60906      NA            NA        NA
# 60907      NA            NA        NA
# 60908      NA            NA        NA
# 60909   Erdr1         Erdr1     Erdr1
#
#                                           gene_name2 gene_biotype  \
# 0                             NM_001011874(Non-Dups)           NM
# 1      NM_001195662#NM_001370921#NM_011283(Non-Dups)           NM
# 2      NM_001195662#NM_001370921#NM_011283(Non-Dups)           NM
# 3      NM_001195662#NM_001370921#NM_011283(Non-Dups)           NM
# 4                                                 NA           NA
# ...                                              ...          ...
# 60905                                             NA           NA
# 60906                                             NA           NA
# 60907                                             NA           NA
# 60908                                             NA           NA
# 60909                  NM_133362#NR_137282(Non-Dups)        NM#NR
#
#       NR_annotation
# 0                NA
# 1                NA
# 2                NA
# 3                NA
# 4                NA
# ...             ...
# 60905            NA
# 60906            NA
# 60907            NA
# 60908            NA
# 60909            NA
#
# [60910 rows x 17 columns]

# %%
df[df['gene_name'] == 'Cyp1a1']
# Out:
#       Chromosome  DRE_Start   DRE_End  DRE_ID DRE_Strand   DRE_MSS  \
# 56655       chr9   57601285  57601304   40865          -  0.920791
# 56656       chr9   57603680  57603699   40866          -  0.980536
# 56657       chr9   57603902  57603921   40867          -  0.914418
# 56658       chr9   57604015  57604034   40868          +  0.934834
# 56659       chr9   57604395  57604414   40869          -  0.905623
#
#       GTF_Chromosome  Gene_Start  Gene_End Gene_Strand Gene_ORIG_Start  \
# 56655           chr9    57585211  57611107           +        57595211
# 56656           chr9    57585211  57611107           +        57595211
# 56657           chr9    57585211  57611107           +        57595211
# 56658           chr9    57585211  57611107           +        57595211
# 56659           chr9    57585211  57611107           +        57595211
#
#       gene_id transcript_id gene_name                        gene_name2  \
# 56655  Cyp1a1        Cyp1a1    Cyp1a1  NM_009992#NM_001136059(Non-Dups)
# 56656  Cyp1a1        Cyp1a1    Cyp1a1  NM_009992#NM_001136059(Non-Dups)
# 56657  Cyp1a1        Cyp1a1    Cyp1a1  NM_009992#NM_001136059(Non-Dups)
# 56658  Cyp1a1        Cyp1a1    Cyp1a1  NM_009992#NM_001136059(Non-Dups)
# 56659  Cyp1a1        Cyp1a1    Cyp1a1  NM_009992#NM_001136059(Non-Dups)
#
#       gene_biotype NR_annotation
# 56655           NM            NA
# 56656           NM            NA
# 56657           NM            NA
# 56658           NM            NA
# 56659           NM            NA

# %%
# Count unique values and their counts in the 'gene_name' column
gene_name_counts = df['gene_name'].value_counts().reset_index()
gene_name_counts.columns = ['gene_name', 'count']

# Create a new DataFrame 'df2' with the unique values and their counts
df2 = gene_name_counts

df2
# Out:
#       gene_name  count
# 0            NA  13328
# 1        Spire1     75
# 2          Wwox     47
# 3         Apbb2     43
# 4          Sdk1     38
# ...         ...    ...
# 23597  lnc14044      1
# 23598  lnc30181      1
# 23599  lnc30180      1
# 23600    Akain1      1
# 23601     Erdr1      1
#
# [23602 rows x 2 columns]

# %%
# Save the DataFrame
df2.to_csv('DRE_Counts_by_Gene.txt', sep='\t', index=False)

# %%
df3 = df.copy()

# %%
# Create a new 'DRE_Avg' column by calculating the average of 'DRE_End' and 'DRE_Start'
df3['DRE_Avg'] = np.ceil((df3['DRE_End'] + df3['DRE_Start']) / 2)


# Convert 'Gene_ORIG_Start' column to a numeric data type, handling the "." values by converting them to NaN
df3['Gene_ORIG_Start_Temp'] = pd.to_numeric(df3['Gene_ORIG_Start'], errors='coerce')


# Initialize the 'Dist_to_Start' column with NaN values
df3['Dist_to_Start'] = None

# Calculate 'Dist_to_Start' based on 'Gene_Strand'
df3.loc[df3['Gene_Strand'] == '-', 'Dist_to_Start'] = df3['Gene_ORIG_Start_Temp'] - df3['DRE_Avg']
df3.loc[df3['Gene_Strand'] == '+', 'Dist_to_Start'] = df3['DRE_Avg'] - df3['Gene_ORIG_Start_Temp']


df3
# Out:
#       Chromosome  DRE_Start   DRE_End  DRE_ID DRE_Strand   DRE_MSS  \
# 0           chr1    3493457   3493476       1          +  0.870102
# 1           chr1    4240913   4240932       2          -  0.877970
# 2           chr1    4427961   4427980       3          +  0.872268
# 3           chr1    4476897   4476916       4          -  0.901051
# 4           chr1    4491129   4491148       5          -  0.867355
# ...          ...        ...       ...     ...        ...       ...
# 60905       chrY   90644962  90644981   44321          +  0.871128
# 60906       chrY   90644966  90644985   44322          +  0.861266
# 60907       chrY   90776986  90777005   44323          -  0.869231
# 60908       chrY   90782870  90782889   44324          +  0.887751
# 60909       chrY   90804927  90804946   44325          -  0.881386
#
#       GTF_Chromosome  Gene_Start  Gene_End Gene_Strand Gene_ORIG_Start  \
# 0               chr1     3284705   3751721           -         3741721
# 1               chr1     4190089   4489464           -         4479464
# 2               chr1     4190089   4489464           -         4479464
# 3               chr1     4190089   4489464           -         4479464
# 4                  .          -1        -1           .               .
# ...              ...         ...       ...         ...             ...
# 60905              .          -1        -1           .               .
# 60906              .          -1        -1           .               .
# 60907              .          -1        -1           .               .
# 60908              .          -1        -1           .               .
# 60909           chrY    90786711  90827734           +        90796711
#
#       gene_id transcript_id gene_name  \
# 0        Xkr4          Xkr4      Xkr4
# 1         Rp1           Rp1       Rp1
# 2         Rp1           Rp1       Rp1
# 3         Rp1           Rp1       Rp1
# 4          NA            NA        NA
# ...       ...           ...       ...
# 60905      NA            NA        NA
# 60906      NA            NA        NA
# 60907      NA            NA        NA
# 60908      NA            NA        NA
# 60909   Erdr1         Erdr1     Erdr1
#
#                                           gene_name2 gene_biotype  \
# 0                             NM_001011874(Non-Dups)           NM
# 1      NM_001195662#NM_001370921#NM_011283(Non-Dups)           NM
# 2      NM_001195662#NM_001370921#NM_011283(Non-Dups)           NM
# 3      NM_001195662#NM_001370921#NM_011283(Non-Dups)           NM
# 4                                                 NA           NA
# ...                                              ...          ...
# 60905                                             NA           NA
# 60906                                             NA           NA
# 60907                                             NA           NA
# 60908                                             NA           NA
# 60909                  NM_133362#NR_137282(Non-Dups)        NM#NR
#
#       NR_annotation     DRE_Avg  Gene_ORIG_Start_Temp Dist_to_Start
# 0                NA   3493467.0             3741721.0      248254.0
# 1                NA   4240923.0             4479464.0      238541.0
# 2                NA   4427971.0             4479464.0       51493.0
# 3                NA   4476907.0             4479464.0        2557.0
# 4                NA   4491139.0                   NaN          None
# ...             ...         ...                   ...           ...
# 60905            NA  90644972.0                   NaN          None
# 60906            NA  90644976.0                   NaN          None
# 60907            NA  90776996.0                   NaN          None
# 60908            NA  90782880.0                   NaN          None
# 60909            NA  90804937.0            90796711.0        8226.0
#
# [60910 rows x 20 columns]

# %%
df3[df3['gene_name'] == 'Cyp1a1']
# Out:
#       Chromosome  DRE_Start   DRE_End  DRE_ID DRE_Strand   DRE_MSS  \
# 56655       chr9   57601285  57601304   40865          -  0.920791
# 56656       chr9   57603680  57603699   40866          -  0.980536
# 56657       chr9   57603902  57603921   40867          -  0.914418
# 56658       chr9   57604015  57604034   40868          +  0.934834
# 56659       chr9   57604395  57604414   40869          -  0.905623
#
#       GTF_Chromosome  Gene_Start  Gene_End Gene_Strand Gene_ORIG_Start  \
# 56655           chr9    57585211  57611107           +        57595211
# 56656           chr9    57585211  57611107           +        57595211
# 56657           chr9    57585211  57611107           +        57595211
# 56658           chr9    57585211  57611107           +        57595211
# 56659           chr9    57585211  57611107           +        57595211
#
#       gene_id transcript_id gene_name                        gene_name2  \
# 56655  Cyp1a1        Cyp1a1    Cyp1a1  NM_009992#NM_001136059(Non-Dups)
# 56656  Cyp1a1        Cyp1a1    Cyp1a1  NM_009992#NM_001136059(Non-Dups)
# 56657  Cyp1a1        Cyp1a1    Cyp1a1  NM_009992#NM_001136059(Non-Dups)
# 56658  Cyp1a1        Cyp1a1    Cyp1a1  NM_009992#NM_001136059(Non-Dups)
# 56659  Cyp1a1        Cyp1a1    Cyp1a1  NM_009992#NM_001136059(Non-Dups)
#
#       gene_biotype NR_annotation     DRE_Avg  Gene_ORIG_Start_Temp  \
# 56655           NM            NA  57601295.0            57595211.0
# 56656           NM            NA  57603690.0            57595211.0
# 56657           NM            NA  57603912.0            57595211.0
# 56658           NM            NA  57604025.0            57595211.0
# 56659           NM            NA  57604405.0            57595211.0
#
#       Dist_to_Start
# 56655        6084.0
# 56656        8479.0
# 56657        8701.0
# 56658        8814.0
# 56659        9194.0

# %%
# Rename the columns
df3 = df3.rename(columns={
    'Chromosome': 'Chr',
    'DRE_Start': 'Start',
    'DRE_End': 'End',
    'DRE_ID': 'DRE_ID',
    'DRE_MSS': 'MSS',
    'GTF_Chromosome': 'GTF_Chrom',
    'Gene_Start': 'Gene_Start',
    'Gene_End': 'Gene_End',
    'Gene_Strand': 'Strand',
    'Gene_ORIG_Start': 'Gene_ORIG_Start',
    'gene_id': 'Gene_ID',
    'transcript_id': 'Transcript_ID',
    'gene_name': 'Gene_Name',
    'gene_name2': 'Gene_Name2',
    'gene_biotype': 'Gene_Biotype',
    'NR_annotation': 'NR_Annotation',
    'Dist_to_Start': 'Dist_to_Start'
})

# Select the desired columns to create a new DataFrame
df_trimmed = df3[['DRE_ID', 'Chr', 'Start', 'End', 
                  'Dist_to_Start',  'Gene_Biotype',
                  'Gene_ID', 'Transcript_ID', 'Gene_Name', 'Gene_Name2','NR_Annotation', 'MSS']]

# %%
df_trimmed.to_csv('MMU_Chromosomal_Location_of_DREs.txt', sep='\t', index=False)
