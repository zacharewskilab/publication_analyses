# %% [markdown]
# # Merge GTF file from Karri et al. with MGI Annotations

# %% [markdown]
# ## <br> 1. Import Required Packages

# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# ## <br> 2. Import and Process Data

# %%
# Convert GTF to BED format
# !gff2bed < ./RAW_Data/Karri_Annotations_Restructured_mm39.gtf > ./RAW_Data/Karri_Annotations_Restructured_mm39.bed
# Out:
# Warning: If your Wiggle data is a significant portion of available system memory, use the --max-mem and --sort-tmpdir options, or use --do-not-sort to disable post-conversion sorting. See --help for more information.

# %%
# Sort BED files by chromosome and start coordinate
# !sort -k1,1 -k2,2n ./RAW_Data/Karri_Annotations_Restructured_mm39.bed > ./RAW_Data/sorted_Karri_Annotations_Restructured_mm39.bed
# !sort -k1,1 -k2,2n ./RAW_Data/MGI_lncRNAs_mm39_Processed.txt > ./RAW_Data/sorted_MGI_lncRNAs_mm39_Processed.bed

# %%
# Perform strand-specific intersection using bedtools
# !bedtools intersect -sorted -loj -a ./RAW_Data/sorted_Karri_Annotations_Restructured_mm39.bed -b ./RAW_Data/sorted_MGI_lncRNAs_mm39_Processed.bed -s > ./RAW_Data/Karri_vs_MGI_lncRNA_Intersection.bed

# %%
# Create a temporary file with headers
# !echo -e "chrom\tstart\tend\tblank\tscore\tstrand\tsource\tfeature\tframe\tattributes\tmgi_chr\tmgi_start\tmgi_end\tmgi_symbol\tmgi_score\tmgi_strand" > ./RAW_Data/Karri_vs_MGI_lncRNA_Intersection_temp.bed

# Append the original intersection data to the temporary file
# !tail -n +2 ./RAW_Data/Karri_vs_MGI_lncRNA_Intersection.bed >> ./RAW_Data/Karri_vs_MGI_lncRNA_Intersection_temp.bed

# Replace the original file with the updated one
# !mv ./RAW_Data/Karri_vs_MGI_lncRNA_Intersection_temp.bed ./RAW_Data/Karri_vs_MGI_lncRNA_Intersection.txt

# %%
# Read the GTF file into a DataFrame
RAW_Master = pd.read_csv('./RAW_Data/Karri_vs_MGI_lncRNA_Intersection.txt', 
                         delimiter='\t', header=0)


RAW_Master
# Out:
# /tmp/local/51093422/ipykernel_1608946/4097613543.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   RAW_Master = pd.read_csv('./RAW_Data/Karri_vs_MGI_lncRNA_Intersection.txt',
#       chrom     start       end blank score strand  \
# 0      chr1   3224554   3224816     .  1000      -
# 1      chr1   3273138   3274559     .  1000      -
# 2      chr1   3275710   3276991     .  1000      -
# 3      chr1   3284704   3741721     .  1000      -
# 4      chr1   3536809   3583776     .  1000      +
# ...     ...       ...       ...   ...   ...    ...
# 84244  chrY  90614769  90617133     .  1000      -
# 84245  chrY  90676614  90678894     .  1000      -
# 84246  chrY  90762408  90766319     .  1000      -
# 84247  chrY  90796710  90827734     .  1000      +
# 84248  chrY  90796710  90827734     .  1000      +
#
#                             source feature frame  \
# 0           Genebody_mm10_lnc48261    exon     .
# 1           Genebody_mm10_lnc48261    exon     .
# 2           Genebody_mm10_lnc48261    exon     .
# 3                 GB_RefseqNM19801    exon     .
# 4                     EnsmblNR4698    exon     .
# ...                            ...     ...   ...
# 84244                 EnsmblNR4698    exon     .
# 84245                 EnsmblNR4698    exon     .
# 84246              GB_RefseqNR2077    exon     .
# 84247  GB_RefseqNM#GB_RefseqNR1159    exon     .
# 84248  GB_RefseqNM#GB_RefseqNR1159    exon     .
#
#                                               attributes mgi_chr  mgi_start  \
# 0      gene_id "lnc_inter_chr1_15560"; transcript_id ...       .         -1
# 1      gene_id "lnc_inter_chr1_15561"; transcript_id ...       .         -1
# 2      gene_id "lnc_inter_chr1_15562"; transcript_id ...       .         -1
# 3      gene_id "Xkr4"; transcript_id "Xkr4"; gene_nam...    chr1    3717532
# 4      gene_id "Gm1992"; transcript_id "Gm1992"; gene...    chr1    3536810
# ...                                                  ...     ...        ...
# 84244  gene_id "Gm28300"; transcript_id "Gm28300"; ge...    chrY   90614770
# 84245  gene_id "Gm28301"; transcript_id "Gm28301"; ge...    chrY   90676615
# 84246  gene_id "G530011O06Rik@chrY(-)"; transcript_id...    chrY   90763696
# 84247  gene_id "Erdr1"; transcript_id "Erdr1"; gene_n...    chrY   90796007
# 84248  gene_id "Erdr1"; transcript_id "Erdr1"; gene_n...    chrY   90804956
#
#         mgi_end      mgi_symbol  mgi_score mgi_strand
# 0            -1               .         -1          .
# 1            -1               .         -1          .
# 2            -1               .         -1          .
# 3       3729127         Gm19938       1000          -
# 4       3583776          Gm1992       1000          +
# ...         ...             ...        ...        ...
# 84244  90617133         Gm28300       1000          -
# 84245  90678894         Gm28301       1000          -
# 84246  90766736  G530011O06Riky       1000          -
# 84247  90827734          Erdr1y       1000          +
# 84248  90820875         Gm33272       1000          +
#
# [84249 rows x 16 columns]

# %%
# Extract information from the 'attributes' column
attributes = RAW_Master['attributes'].str.split(';', expand=True)

attributes


# Extract specific attributes you're interested in
RAW_Master['gene_id'] = attributes[0].str.strip().str.split(' ', expand=True)[1].str.strip('"')
RAW_Master['transcript_id'] = attributes[1].str.strip().str.split(' ', expand=True)[1].str.strip('"')
RAW_Master['gene_name'] = attributes[2].str.strip().str.split(' ', expand=True)[1].str.strip('"')
RAW_Master['gene_biotype'] = attributes[4].str.strip().str.split(' ', expand=True)[1].str.strip('"')
RAW_Master['NR_annotation'] = attributes[5].str.strip().str.split(' ', expand=True)[1].str.strip('"')
RAW_Master['NR_annotation2'] = RAW_Master['NR_annotation'].str.split('_').str[1]

# Drop the original 'attributes' column
RAW_Master.drop(columns=['attributes'], inplace=True)

RAW_Master
# Out:
#       chrom     start       end blank score strand  \
# 0      chr1   3224554   3224816     .  1000      -
# 1      chr1   3273138   3274559     .  1000      -
# 2      chr1   3275710   3276991     .  1000      -
# 3      chr1   3284704   3741721     .  1000      -
# 4      chr1   3536809   3583776     .  1000      +
# ...     ...       ...       ...   ...   ...    ...
# 84244  chrY  90614769  90617133     .  1000      -
# 84245  chrY  90676614  90678894     .  1000      -
# 84246  chrY  90762408  90766319     .  1000      -
# 84247  chrY  90796710  90827734     .  1000      +
# 84248  chrY  90796710  90827734     .  1000      +
#
#                             source feature frame mgi_chr  ...   mgi_end  \
# 0           Genebody_mm10_lnc48261    exon     .       .  ...        -1
# 1           Genebody_mm10_lnc48261    exon     .       .  ...        -1
# 2           Genebody_mm10_lnc48261    exon     .       .  ...        -1
# 3                 GB_RefseqNM19801    exon     .    chr1  ...   3729127
# 4                     EnsmblNR4698    exon     .    chr1  ...   3583776
# ...                            ...     ...   ...     ...  ...       ...
# 84244                 EnsmblNR4698    exon     .    chrY  ...  90617133
# 84245                 EnsmblNR4698    exon     .    chrY  ...  90678894
# 84246              GB_RefseqNR2077    exon     .    chrY  ...  90766736
# 84247  GB_RefseqNM#GB_RefseqNR1159    exon     .    chrY  ...  90827734
# 84248  GB_RefseqNM#GB_RefseqNR1159    exon     .    chrY  ...  90820875
#
#            mgi_symbol mgi_score  mgi_strand                gene_id  \
# 0                   .        -1           .   lnc_inter_chr1_15560
# 1                   .        -1           .   lnc_inter_chr1_15561
# 2                   .        -1           .   lnc_inter_chr1_15562
# 3             Gm19938      1000           -                   Xkr4
# 4              Gm1992      1000           +                 Gm1992
# ...               ...       ...         ...                    ...
# 84244         Gm28300      1000           -                Gm28300
# 84245         Gm28301      1000           -                Gm28301
# 84246  G530011O06Riky      1000           -  G530011O06Rik@chrY(-)
# 84247          Erdr1y      1000           +                  Erdr1
# 84248         Gm33272      1000           +                  Erdr1
#
#                transcript_id              gene_name gene_biotype  \
# 0       lnc_inter_chr1_15560               lnc15560       lncRNA
# 1       lnc_inter_chr1_15561               lnc15561       lncRNA
# 2       lnc_inter_chr1_15562               lnc15562       lncRNA
# 3                       Xkr4                   Xkr4           NM
# 4                     Gm1992                 Gm1992    antisense
# ...                      ...                    ...          ...
# 84244                Gm28300                Gm28300      lincRNA
# 84245                Gm28301                Gm28301      lincRNA
# 84246  G530011O06Rik@chrY(-)  G530011O06Rik@chrY(-)           NR
# 84247                  Erdr1                  Erdr1        NM#NR
# 84248                  Erdr1                  Erdr1        NM#NR
#
#       NR_annotation NR_annotation2
# 0          lnc15560            NaN
# 1          lnc15561            NaN
# 2          lnc15562            NaN
# 3              None           None
# 4              None           None
# ...             ...            ...
# 84244          None           None
# 84245          None           None
# 84246          None           None
# 84247          None           None
# 84248          None           None
#
# [84249 rows x 21 columns]

# %%
# Check unique gene biotypes in RAW_Master
RAW_Master['gene_biotype'].unique()
# Out:
# array(['lncRNA', 'NM', 'antisense', 'lincRNA', 'NM#NR', 'NR',
#        'lncOfInterest', None], dtype=object)

# %%
# Identify rows where gene_biotype is the string 'None'
RAW_Master[RAW_Master['gene_biotype'].astype(str) == 'None']
# Out:
#       chrom  start    end blank score strand source feature frame mgi_chr  \
# 80642  chrM   2750   3707     .     .      +  insdc    exon     .       .
# 80643  chrM   3913   4951     .     .      +  insdc    exon     .       .
# 80644  chrM   5327   6872     .     .      +  insdc    exon     .       .
# 80645  chrM   7012   7696     .     .      +  insdc    exon     .       .
# 80646  chrM   7765   7969     .     .      +  insdc    exon     .       .
# 80647  chrM   7926   8607     .     .      +  insdc    exon     .       .
# 80648  chrM   8606   9390     .     .      +  insdc    exon     .       .
# 80649  chrM   9458   9806     .     .      +  insdc    exon     .       .
# 80650  chrM   9876  10173     .     .      +  insdc    exon     .       .
# 80651  chrM  10166  11544     .     .      +  insdc    exon     .       .
# 80652  chrM  11741  13565     .     .      +  insdc    exon     .       .
# 80653  chrM  13551  14070     .     .      -  insdc    exon     .       .
# 80654  chrM  14144  15288     .     .      +  insdc    exon     .       .
#
#        ...  mgi_end  mgi_symbol mgi_score  mgi_strand             gene_id  \
# 80642  ...       -1           .        -1           .  ENSMUSG00000064341
# 80643  ...       -1           .        -1           .  ENSMUSG00000064345
# 80644  ...       -1           .        -1           .  ENSMUSG00000064351
# 80645  ...       -1           .        -1           .  ENSMUSG00000064354
# 80646  ...       -1           .        -1           .  ENSMUSG00000064356
# 80647  ...       -1           .        -1           .  ENSMUSG00000064357
# 80648  ...       -1           .        -1           .  ENSMUSG00000064358
# 80649  ...       -1           .        -1           .  ENSMUSG00000064360
# 80650  ...       -1           .        -1           .  ENSMUSG00000065947
# 80651  ...       -1           .        -1           .  ENSMUSG00000064363
# 80652  ...       -1           .        -1           .  ENSMUSG00000064367
# 80653  ...       -1           .        -1           .  ENSMUSG00000064368
# 80654  ...       -1           .        -1           .  ENSMUSG00000064370
#
#             transcript_id gene_name gene_biotype NR_annotation NR_annotation2
# 80642  ENSMUSG00000064341    mt-Nd1         None          None           None
# 80643  ENSMUSG00000064345    mt-Nd2         None          None           None
# 80644  ENSMUSG00000064351    mt-Co1         None          None           None
# 80645  ENSMUSG00000064354    mt-Co2         None          None           None
# 80646  ENSMUSG00000064356   mt-Atp8         None          None           None
# 80647  ENSMUSG00000064357   mt-Atp6         None          None           None
# 80648  ENSMUSG00000064358    mt-Co3         None          None           None
# 80649  ENSMUSG00000064360    mt-Nd3         None          None           None
# 80650  ENSMUSG00000065947   mt-Nd4l         None          None           None
# 80651  ENSMUSG00000064363    mt-Nd4         None          None           None
# 80652  ENSMUSG00000064367    mt-Nd5         None          None           None
# 80653  ENSMUSG00000064368    mt-Nd6         None          None           None
# 80654  ENSMUSG00000064370   mt-Cytb         None          None           None
#
# [13 rows x 21 columns]

# %%
# Replace NaNs in gene_biotype with 'mitochondrial protein-coding gene' and check updated unique values
RAW_Master.loc[RAW_Master['gene_biotype'].isna(), 'gene_biotype'] = 'mitochondrial protein-coding gene'
RAW_Master['gene_biotype'].unique()
# Out:
# array(['lncRNA', 'NM', 'antisense', 'lincRNA', 'NM#NR', 'NR',
#        'lncOfInterest', 'mitochondrial protein-coding gene'], dtype=object)

# %% [markdown]
# ## <br> 2. Export Processed Dataframe

# %%
RAW_Master.to_csv('MGI_and_Karri_Annotations_Restructured_mm39.txt', sep='\t', index=False, header=True)
