# %% [markdown]
# # Export Desq2 Results for Excel

# %% [markdown]
# ### 1. Import Required Packages
# ### 2. Import Data
# ### 3. Concat All Data Into One Dataframe

# %% [markdown]
# ## <br> 1. Import Required Packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# Set figure parameters.

# %%
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}
# %config InlineBackend.figure_format='retina'
pd.options.display.max_colwidth = 200
#plt.rcParams['font.sans-serif']=['Arial']
plt.rcParams['pdf.fonttype'] = 'truetype'

# %% [markdown]
# ## <br> 2. Import Deseq2 Data

# %%
Deseq2_LyECs_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/LyECs_2.txt', delimiter = '\t').reset_index()
Deseq2_LyECs_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/LyECs_4.txt', delimiter = '\t').reset_index()
Deseq2_LyECs_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/LyECs_8.txt', delimiter = '\t').reset_index()
Deseq2_LyECs_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/LyECs_12.txt', delimiter = '\t').reset_index()
Deseq2_LyECs_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/LyECs_18.txt', delimiter = '\t').reset_index()
Deseq2_LyECs_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/LyECs_24.txt', delimiter = '\t').reset_index()
Deseq2_LyECs_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/LyECs_72.txt', delimiter = '\t').reset_index()
Deseq2_Midzonal_LSECs_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Midzonal_LSECs_2.txt', delimiter = '\t').reset_index()
Deseq2_Midzonal_LSECs_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Midzonal_LSECs_4.txt', delimiter = '\t').reset_index()
Deseq2_Midzonal_LSECs_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Midzonal_LSECs_8.txt', delimiter = '\t').reset_index()
Deseq2_Midzonal_LSECs_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Midzonal_LSECs_12.txt', delimiter = '\t').reset_index()
Deseq2_Midzonal_LSECs_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Midzonal_LSECs_18.txt', delimiter = '\t').reset_index()
Deseq2_Midzonal_LSECs_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Midzonal_LSECs_24.txt', delimiter = '\t').reset_index()
Deseq2_Midzonal_LSECs_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Midzonal_LSECs_72.txt', delimiter = '\t').reset_index()
Deseq2_PECs_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/PECs_2.txt', delimiter = '\t').reset_index()
Deseq2_PECs_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/PECs_4.txt', delimiter = '\t').reset_index()
Deseq2_PECs_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/PECs_8.txt', delimiter = '\t').reset_index()
Deseq2_PECs_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/PECs_12.txt', delimiter = '\t').reset_index()
Deseq2_PECs_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/PECs_18.txt', delimiter = '\t').reset_index()
Deseq2_PECs_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/PECs_24.txt', delimiter = '\t').reset_index()
Deseq2_PECs_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/PECs_72.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_LSECs_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_LSECs_2.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_LSECs_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_LSECs_4.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_LSECs_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_LSECs_8.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_LSECs_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_LSECs_12.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_LSECs_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_LSECs_18.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_LSECs_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_LSECs_24.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_LSECs_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_LSECs_72.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_VECs_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_VECs_2.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_VECs_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_VECs_4.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_VECs_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_VECs_8.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_VECs_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_VECs_12.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_VECs_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_VECs_18.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_VECs_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_VECs_24.txt', delimiter = '\t').reset_index()
Deseq2_Pericentral_VECs_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Pericentral_VECs_72.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_LSECs_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_LSECs_2.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_LSECs_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_LSECs_4.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_LSECs_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_LSECs_8.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_LSECs_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_LSECs_12.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_LSECs_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_LSECs_18.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_LSECs_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_LSECs_24.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_LSECs_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_LSECs_72.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_VECs_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_VECs_2.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_VECs_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_VECs_4.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_VECs_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_VECs_8.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_VECs_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_VECs_12.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_VECs_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_VECs_18.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_VECs_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_VECs_24.txt', delimiter = '\t').reset_index()
Deseq2_Periportal_VECs_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Periportal_VECs_72.txt', delimiter = '\t').reset_index()
Deseq2_Unknown_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Unknown_2.txt', delimiter = '\t').reset_index()
Deseq2_Unknown_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Unknown_4.txt', delimiter = '\t').reset_index()
Deseq2_Unknown_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Unknown_8.txt', delimiter = '\t').reset_index()
Deseq2_Unknown_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Unknown_12.txt', delimiter = '\t').reset_index()
Deseq2_Unknown_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Unknown_18.txt', delimiter = '\t').reset_index()
Deseq2_Unknown_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Unknown_24.txt', delimiter = '\t').reset_index()
Deseq2_Unknown_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis-EC_CELLS_ONLY---Deseq2/Results/Unknown_72.txt', delimiter = '\t').reset_index()

# %%
Deseq2_LyECs_2['FoldChange'] = 2 ** Deseq2_LyECs_2['log2FoldChange']
Deseq2_LyECs_4['FoldChange'] = 2 ** Deseq2_LyECs_4['log2FoldChange']
Deseq2_LyECs_8['FoldChange'] = 2 ** Deseq2_LyECs_8['log2FoldChange']
Deseq2_LyECs_12['FoldChange'] = 2 ** Deseq2_LyECs_12['log2FoldChange']
Deseq2_LyECs_18['FoldChange'] = 2 ** Deseq2_LyECs_18['log2FoldChange']
Deseq2_LyECs_24['FoldChange'] = 2 ** Deseq2_LyECs_24['log2FoldChange']
Deseq2_LyECs_72['FoldChange'] = 2 ** Deseq2_LyECs_72['log2FoldChange']
Deseq2_Midzonal_LSECs_2['FoldChange'] = 2 ** Deseq2_Midzonal_LSECs_2['log2FoldChange']
Deseq2_Midzonal_LSECs_4['FoldChange'] = 2 ** Deseq2_Midzonal_LSECs_4['log2FoldChange']
Deseq2_Midzonal_LSECs_8['FoldChange'] = 2 ** Deseq2_Midzonal_LSECs_8['log2FoldChange']
Deseq2_Midzonal_LSECs_12['FoldChange'] = 2 ** Deseq2_Midzonal_LSECs_12['log2FoldChange']
Deseq2_Midzonal_LSECs_18['FoldChange'] = 2 ** Deseq2_Midzonal_LSECs_18['log2FoldChange']
Deseq2_Midzonal_LSECs_24['FoldChange'] = 2 ** Deseq2_Midzonal_LSECs_24['log2FoldChange']
Deseq2_Midzonal_LSECs_72['FoldChange'] = 2 ** Deseq2_Midzonal_LSECs_72['log2FoldChange']
Deseq2_PECs_2['FoldChange'] = 2 ** Deseq2_PECs_2['log2FoldChange']
Deseq2_PECs_4['FoldChange'] = 2 ** Deseq2_PECs_4['log2FoldChange']
Deseq2_PECs_8['FoldChange'] = 2 ** Deseq2_PECs_8['log2FoldChange']
Deseq2_PECs_12['FoldChange'] = 2 ** Deseq2_PECs_12['log2FoldChange']
Deseq2_PECs_18['FoldChange'] = 2 ** Deseq2_PECs_18['log2FoldChange']
Deseq2_PECs_24['FoldChange'] = 2 ** Deseq2_PECs_24['log2FoldChange']
Deseq2_PECs_72['FoldChange'] = 2 ** Deseq2_PECs_72['log2FoldChange']
Deseq2_Pericentral_LSECs_2['FoldChange'] = 2 ** Deseq2_Pericentral_LSECs_2['log2FoldChange']
Deseq2_Pericentral_LSECs_4['FoldChange'] = 2 ** Deseq2_Pericentral_LSECs_4['log2FoldChange']
Deseq2_Pericentral_LSECs_8['FoldChange'] = 2 ** Deseq2_Pericentral_LSECs_8['log2FoldChange']
Deseq2_Pericentral_LSECs_12['FoldChange'] = 2 ** Deseq2_Pericentral_LSECs_12['log2FoldChange']
Deseq2_Pericentral_LSECs_18['FoldChange'] = 2 ** Deseq2_Pericentral_LSECs_18['log2FoldChange']
Deseq2_Pericentral_LSECs_24['FoldChange'] = 2 ** Deseq2_Pericentral_LSECs_24['log2FoldChange']
Deseq2_Pericentral_LSECs_72['FoldChange'] = 2 ** Deseq2_Pericentral_LSECs_72['log2FoldChange']
Deseq2_Pericentral_VECs_2['FoldChange'] = 2 ** Deseq2_Pericentral_VECs_2['log2FoldChange']
Deseq2_Pericentral_VECs_4['FoldChange'] = 2 ** Deseq2_Pericentral_VECs_4['log2FoldChange']
Deseq2_Pericentral_VECs_8['FoldChange'] = 2 ** Deseq2_Pericentral_VECs_8['log2FoldChange']
Deseq2_Pericentral_VECs_12['FoldChange'] = 2 ** Deseq2_Pericentral_VECs_12['log2FoldChange']
Deseq2_Pericentral_VECs_18['FoldChange'] = 2 ** Deseq2_Pericentral_VECs_18['log2FoldChange']
Deseq2_Pericentral_VECs_24['FoldChange'] = 2 ** Deseq2_Pericentral_VECs_24['log2FoldChange']
Deseq2_Pericentral_VECs_72['FoldChange'] = 2 ** Deseq2_Pericentral_VECs_72['log2FoldChange']
Deseq2_Periportal_LSECs_2['FoldChange'] = 2 ** Deseq2_Periportal_LSECs_2['log2FoldChange']
Deseq2_Periportal_LSECs_4['FoldChange'] = 2 ** Deseq2_Periportal_LSECs_4['log2FoldChange']
Deseq2_Periportal_LSECs_8['FoldChange'] = 2 ** Deseq2_Periportal_LSECs_8['log2FoldChange']
Deseq2_Periportal_LSECs_12['FoldChange'] = 2 ** Deseq2_Periportal_LSECs_12['log2FoldChange']
Deseq2_Periportal_LSECs_18['FoldChange'] = 2 ** Deseq2_Periportal_LSECs_18['log2FoldChange']
Deseq2_Periportal_LSECs_24['FoldChange'] = 2 ** Deseq2_Periportal_LSECs_24['log2FoldChange']
Deseq2_Periportal_LSECs_72['FoldChange'] = 2 ** Deseq2_Periportal_LSECs_72['log2FoldChange']
Deseq2_Periportal_VECs_2['FoldChange'] = 2 ** Deseq2_Periportal_VECs_2['log2FoldChange']
Deseq2_Periportal_VECs_4['FoldChange'] = 2 ** Deseq2_Periportal_VECs_4['log2FoldChange']
Deseq2_Periportal_VECs_8['FoldChange'] = 2 ** Deseq2_Periportal_VECs_8['log2FoldChange']
Deseq2_Periportal_VECs_12['FoldChange'] = 2 ** Deseq2_Periportal_VECs_12['log2FoldChange']
Deseq2_Periportal_VECs_18['FoldChange'] = 2 ** Deseq2_Periportal_VECs_18['log2FoldChange']
Deseq2_Periportal_VECs_24['FoldChange'] = 2 ** Deseq2_Periportal_VECs_24['log2FoldChange']
Deseq2_Periportal_VECs_72['FoldChange'] = 2 ** Deseq2_Periportal_VECs_72['log2FoldChange']
Deseq2_Unknown_2['FoldChange'] = 2 ** Deseq2_Unknown_2['log2FoldChange']
Deseq2_Unknown_4['FoldChange'] = 2 ** Deseq2_Unknown_4['log2FoldChange']
Deseq2_Unknown_8['FoldChange'] = 2 ** Deseq2_Unknown_8['log2FoldChange']
Deseq2_Unknown_12['FoldChange'] = 2 ** Deseq2_Unknown_12['log2FoldChange']
Deseq2_Unknown_18['FoldChange'] = 2 ** Deseq2_Unknown_18['log2FoldChange']
Deseq2_Unknown_24['FoldChange'] = 2 ** Deseq2_Unknown_24['log2FoldChange']
Deseq2_Unknown_72['FoldChange'] = 2 ** Deseq2_Unknown_72['log2FoldChange']

# %%
Deseq2_LyECs_2 = Deseq2_LyECs_2.rename(columns={'index': 'Gene'})
Deseq2_LyECs_4 = Deseq2_LyECs_4.rename(columns={'index': 'Gene'})
Deseq2_LyECs_8 = Deseq2_LyECs_8.rename(columns={'index': 'Gene'})
Deseq2_LyECs_12 = Deseq2_LyECs_12.rename(columns={'index': 'Gene'})
Deseq2_LyECs_18 = Deseq2_LyECs_18.rename(columns={'index': 'Gene'})
Deseq2_LyECs_24 = Deseq2_LyECs_24.rename(columns={'index': 'Gene'})
Deseq2_LyECs_72 = Deseq2_LyECs_72.rename(columns={'index': 'Gene'})
Deseq2_Midzonal_LSECs_2 = Deseq2_Midzonal_LSECs_2.rename(columns={'index': 'Gene'})
Deseq2_Midzonal_LSECs_4 = Deseq2_Midzonal_LSECs_4.rename(columns={'index': 'Gene'})
Deseq2_Midzonal_LSECs_8 = Deseq2_Midzonal_LSECs_8.rename(columns={'index': 'Gene'})
Deseq2_Midzonal_LSECs_12 = Deseq2_Midzonal_LSECs_12.rename(columns={'index': 'Gene'})
Deseq2_Midzonal_LSECs_18 = Deseq2_Midzonal_LSECs_18.rename(columns={'index': 'Gene'})
Deseq2_Midzonal_LSECs_24 = Deseq2_Midzonal_LSECs_24.rename(columns={'index': 'Gene'})
Deseq2_Midzonal_LSECs_72 = Deseq2_Midzonal_LSECs_72.rename(columns={'index': 'Gene'})
Deseq2_PECs_2 = Deseq2_PECs_2.rename(columns={'index': 'Gene'})
Deseq2_PECs_4 = Deseq2_PECs_4.rename(columns={'index': 'Gene'})
Deseq2_PECs_8 = Deseq2_PECs_8.rename(columns={'index': 'Gene'})
Deseq2_PECs_12 = Deseq2_PECs_12.rename(columns={'index': 'Gene'})
Deseq2_PECs_18 = Deseq2_PECs_18.rename(columns={'index': 'Gene'})
Deseq2_PECs_24 = Deseq2_PECs_24.rename(columns={'index': 'Gene'})
Deseq2_PECs_72 = Deseq2_PECs_72.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_LSECs_2 = Deseq2_Pericentral_LSECs_2.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_LSECs_4 = Deseq2_Pericentral_LSECs_4.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_LSECs_8 = Deseq2_Pericentral_LSECs_8.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_LSECs_12 = Deseq2_Pericentral_LSECs_12.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_LSECs_18 = Deseq2_Pericentral_LSECs_18.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_LSECs_24 = Deseq2_Pericentral_LSECs_24.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_LSECs_72 = Deseq2_Pericentral_LSECs_72.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_VECs_2 = Deseq2_Pericentral_VECs_2.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_VECs_4 = Deseq2_Pericentral_VECs_4.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_VECs_8 = Deseq2_Pericentral_VECs_8.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_VECs_12 = Deseq2_Pericentral_VECs_12.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_VECs_18 = Deseq2_Pericentral_VECs_18.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_VECs_24 = Deseq2_Pericentral_VECs_24.rename(columns={'index': 'Gene'})
Deseq2_Pericentral_VECs_72 = Deseq2_Pericentral_VECs_72.rename(columns={'index': 'Gene'})
Deseq2_Periportal_LSECs_2 = Deseq2_Periportal_LSECs_2.rename(columns={'index': 'Gene'})
Deseq2_Periportal_LSECs_4 = Deseq2_Periportal_LSECs_4.rename(columns={'index': 'Gene'})
Deseq2_Periportal_LSECs_8 = Deseq2_Periportal_LSECs_8.rename(columns={'index': 'Gene'})
Deseq2_Periportal_LSECs_12 = Deseq2_Periportal_LSECs_12.rename(columns={'index': 'Gene'})
Deseq2_Periportal_LSECs_18 = Deseq2_Periportal_LSECs_18.rename(columns={'index': 'Gene'})
Deseq2_Periportal_LSECs_24 = Deseq2_Periportal_LSECs_24.rename(columns={'index': 'Gene'})
Deseq2_Periportal_LSECs_72 = Deseq2_Periportal_LSECs_72.rename(columns={'index': 'Gene'})
Deseq2_Periportal_VECs_2 = Deseq2_Periportal_VECs_2.rename(columns={'index': 'Gene'})
Deseq2_Periportal_VECs_4 = Deseq2_Periportal_VECs_4.rename(columns={'index': 'Gene'})
Deseq2_Periportal_VECs_8 = Deseq2_Periportal_VECs_8.rename(columns={'index': 'Gene'})
Deseq2_Periportal_VECs_12 = Deseq2_Periportal_VECs_12.rename(columns={'index': 'Gene'})
Deseq2_Periportal_VECs_18 = Deseq2_Periportal_VECs_18.rename(columns={'index': 'Gene'})
Deseq2_Periportal_VECs_24 = Deseq2_Periportal_VECs_24.rename(columns={'index': 'Gene'})
Deseq2_Periportal_VECs_72 = Deseq2_Periportal_VECs_72.rename(columns={'index': 'Gene'})
Deseq2_Unknown_2 = Deseq2_Unknown_2.rename(columns={'index': 'Gene'})
Deseq2_Unknown_4 = Deseq2_Unknown_4.rename(columns={'index': 'Gene'})
Deseq2_Unknown_8 = Deseq2_Unknown_8.rename(columns={'index': 'Gene'})
Deseq2_Unknown_12 = Deseq2_Unknown_12.rename(columns={'index': 'Gene'})
Deseq2_Unknown_18 = Deseq2_Unknown_18.rename(columns={'index': 'Gene'})
Deseq2_Unknown_24 = Deseq2_Unknown_24.rename(columns={'index': 'Gene'})
Deseq2_Unknown_72 = Deseq2_Unknown_72.rename(columns={'index': 'Gene'})

# %%
Deseq2_Unknown_72
# Out:
#          Gene     baseMean  log2FoldChange     lfcSE      stat    pvalue
# 0     Gm42418  1401.041965       -0.085945  0.569875 -0.150813  0.880123  \
# 1      Malat1   464.665504        0.059039  0.220458  0.267802  0.788851
# 2       Cmss1   220.186902       -0.363381  0.559506 -0.649468  0.516036
# 3       Stab2    92.578009       -0.508876  0.333177 -1.527342  0.126676
# 4      Camk1d    94.325293       -0.064847  0.382160 -0.169686  0.865257
# ...       ...          ...             ...       ...       ...       ...
# 4439   Ubxn2a     1.071625        0.379140  1.356764  0.279444  0.779904
# 4440    Utp11     0.892990       -3.091406  1.708405 -1.809527  0.070369
# 4441    Vdac1     0.842426        1.551787  1.599392  0.970236  0.331929
# 4442    Wdfy1     0.964786        0.870753  1.503533  0.579138  0.562496
# 4443   Zfp746     1.084743        1.022052  1.430094  0.714674  0.474810
#
#           padj  FoldChange
# 0     0.997212    0.942167
# 1     0.997212    1.041772
# ...

# %%
Deseq2_LyECs_2 = Deseq2_LyECs_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_LyECs_4 = Deseq2_LyECs_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_LyECs_8 = Deseq2_LyECs_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_LyECs_12 = Deseq2_LyECs_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_LyECs_18 = Deseq2_LyECs_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_LyECs_24 = Deseq2_LyECs_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_LyECs_72 = Deseq2_LyECs_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Midzonal_LSECs_2 = Deseq2_Midzonal_LSECs_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Midzonal_LSECs_4 = Deseq2_Midzonal_LSECs_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Midzonal_LSECs_8 = Deseq2_Midzonal_LSECs_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Midzonal_LSECs_12 = Deseq2_Midzonal_LSECs_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Midzonal_LSECs_18 = Deseq2_Midzonal_LSECs_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Midzonal_LSECs_24 = Deseq2_Midzonal_LSECs_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Midzonal_LSECs_72 = Deseq2_Midzonal_LSECs_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PECs_2 = Deseq2_PECs_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PECs_4 = Deseq2_PECs_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PECs_8 = Deseq2_PECs_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PECs_12 = Deseq2_PECs_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PECs_18 = Deseq2_PECs_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PECs_24 = Deseq2_PECs_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PECs_72 = Deseq2_PECs_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_LSECs_2 = Deseq2_Pericentral_LSECs_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_LSECs_4 = Deseq2_Pericentral_LSECs_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_LSECs_8 = Deseq2_Pericentral_LSECs_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_LSECs_12 = Deseq2_Pericentral_LSECs_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_LSECs_18 = Deseq2_Pericentral_LSECs_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_LSECs_24 = Deseq2_Pericentral_LSECs_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_LSECs_72 = Deseq2_Pericentral_LSECs_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_VECs_2 = Deseq2_Pericentral_VECs_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_VECs_4 = Deseq2_Pericentral_VECs_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_VECs_8 = Deseq2_Pericentral_VECs_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_VECs_12 = Deseq2_Pericentral_VECs_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_VECs_18 = Deseq2_Pericentral_VECs_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_VECs_24 = Deseq2_Pericentral_VECs_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Pericentral_VECs_72 = Deseq2_Pericentral_VECs_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_LSECs_2 = Deseq2_Periportal_LSECs_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_LSECs_4 = Deseq2_Periportal_LSECs_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_LSECs_8 = Deseq2_Periportal_LSECs_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_LSECs_12 = Deseq2_Periportal_LSECs_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_LSECs_18 = Deseq2_Periportal_LSECs_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_LSECs_24 = Deseq2_Periportal_LSECs_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_LSECs_72 = Deseq2_Periportal_LSECs_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_VECs_2 = Deseq2_Periportal_VECs_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_VECs_4 = Deseq2_Periportal_VECs_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_VECs_8 = Deseq2_Periportal_VECs_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_VECs_12 = Deseq2_Periportal_VECs_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_VECs_18 = Deseq2_Periportal_VECs_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_VECs_24 = Deseq2_Periportal_VECs_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Periportal_VECs_72 = Deseq2_Periportal_VECs_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Unknown_2 = Deseq2_Unknown_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Unknown_4 = Deseq2_Unknown_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Unknown_8 = Deseq2_Unknown_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Unknown_12 = Deseq2_Unknown_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Unknown_18 = Deseq2_Unknown_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Unknown_24 = Deseq2_Unknown_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Unknown_72 = Deseq2_Unknown_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]

# %%
Deseq2_Unknown_24[Deseq2_Unknown_24['Gene'] == 'Kit']
# Out:
#     Gene   baseMean  log2FoldChange     lfcSE  FoldChange      padj
# 292  Kit  11.198094        0.344648  0.719273    1.269841  0.996865

# %%
Deseq2_LyECs_2 = Deseq2_LyECs_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_LyECs_4 = Deseq2_LyECs_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_LyECs_8 = Deseq2_LyECs_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_LyECs_12 = Deseq2_LyECs_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_LyECs_18 = Deseq2_LyECs_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_LyECs_24 = Deseq2_LyECs_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_LyECs_72 = Deseq2_LyECs_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_Midzonal_LSECs_2 = Deseq2_Midzonal_LSECs_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_Midzonal_LSECs_4 = Deseq2_Midzonal_LSECs_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_Midzonal_LSECs_8 = Deseq2_Midzonal_LSECs_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_Midzonal_LSECs_12 = Deseq2_Midzonal_LSECs_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_Midzonal_LSECs_18 = Deseq2_Midzonal_LSECs_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_Midzonal_LSECs_24 = Deseq2_Midzonal_LSECs_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_Midzonal_LSECs_72 = Deseq2_Midzonal_LSECs_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_PECs_2 = Deseq2_PECs_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_PECs_4 = Deseq2_PECs_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_PECs_8 = Deseq2_PECs_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_PECs_12 = Deseq2_PECs_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_PECs_18 = Deseq2_PECs_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_PECs_24 = Deseq2_PECs_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_PECs_72 = Deseq2_PECs_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_Pericentral_LSECs_2 = Deseq2_Pericentral_LSECs_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_Pericentral_LSECs_4 = Deseq2_Pericentral_LSECs_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_Pericentral_LSECs_8 = Deseq2_Pericentral_LSECs_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_Pericentral_LSECs_12 = Deseq2_Pericentral_LSECs_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_Pericentral_LSECs_18 = Deseq2_Pericentral_LSECs_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_Pericentral_LSECs_24 = Deseq2_Pericentral_LSECs_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_Pericentral_LSECs_72 = Deseq2_Pericentral_LSECs_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_Pericentral_VECs_2 = Deseq2_Pericentral_VECs_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_Pericentral_VECs_4 = Deseq2_Pericentral_VECs_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_Pericentral_VECs_8 = Deseq2_Pericentral_VECs_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_Pericentral_VECs_12 = Deseq2_Pericentral_VECs_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_Pericentral_VECs_18 = Deseq2_Pericentral_VECs_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_Pericentral_VECs_24 = Deseq2_Pericentral_VECs_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_Pericentral_VECs_72 = Deseq2_Pericentral_VECs_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_Periportal_LSECs_2 = Deseq2_Periportal_LSECs_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_Periportal_LSECs_4 = Deseq2_Periportal_LSECs_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_Periportal_LSECs_8 = Deseq2_Periportal_LSECs_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_Periportal_LSECs_12 = Deseq2_Periportal_LSECs_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_Periportal_LSECs_18 = Deseq2_Periportal_LSECs_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_Periportal_LSECs_24 = Deseq2_Periportal_LSECs_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_Periportal_LSECs_72 = Deseq2_Periportal_LSECs_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_Periportal_VECs_2 = Deseq2_Periportal_VECs_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_Periportal_VECs_4 = Deseq2_Periportal_VECs_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_Periportal_VECs_8 = Deseq2_Periportal_VECs_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_Periportal_VECs_12 = Deseq2_Periportal_VECs_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_Periportal_VECs_18 = Deseq2_Periportal_VECs_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_Periportal_VECs_24 = Deseq2_Periportal_VECs_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_Periportal_VECs_72 = Deseq2_Periportal_VECs_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_Unknown_2 = Deseq2_Unknown_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_Unknown_4 = Deseq2_Unknown_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_Unknown_8 = Deseq2_Unknown_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_Unknown_12 = Deseq2_Unknown_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_Unknown_18 = Deseq2_Unknown_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_Unknown_24 = Deseq2_Unknown_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_Unknown_72 = Deseq2_Unknown_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})

# %%
Deseq2_Unknown_24
# Out:
#          Gene  baseMean_24  log2FoldChange_24  lfcSE_24  FoldChange_24
# 0     Gm42418  1401.041965          -0.519537  0.570251       0.697596  \
# 1      Malat1   464.665504           0.440286  0.223730       1.356874
# 2       Cmss1   220.186902          -0.348967  0.562256       0.785146
# 3       Stab2    92.578009           0.215468  0.350729       1.161081
# 4      Camk1d    94.325293           0.167402  0.391487       1.123034
# ...       ...          ...                ...       ...            ...
# 4439   Ubxn2a     1.071625           0.216741  1.358313       1.162105
# 4440    Utp11     0.892990          -0.242713  1.627677       0.845154
# 4441    Vdac1     0.842426          -1.431371  1.514358       0.370778
# 4442    Wdfy1     0.964786          -0.713271  1.518666       0.609936
# 4443   Zfp746     1.084743           0.868770  1.570079       1.826106
#
#        padj_24
# 0     0.996865
# 1     0.996865
# 2     0.996865
# 3     0.996865
# 4     0.996865
# ...        ...
# ...

# %% [markdown]
# ## <br> 3. Merge All Data Into One Dataframe Fro each Cell

# %%
merged_df_LyECs = Deseq2_LyECs_2.merge(Deseq2_LyECs_4, on='Gene', how='outer')
merged_df_LyECs = merged_df_LyECs.merge(Deseq2_LyECs_8, on='Gene', how='outer')
merged_df_LyECs = merged_df_LyECs.merge(Deseq2_LyECs_12, on='Gene', how='outer')
merged_df_LyECs = merged_df_LyECs.merge(Deseq2_LyECs_18, on='Gene', how='outer')
merged_df_LyECs = merged_df_LyECs.merge(Deseq2_LyECs_24, on='Gene', how='outer')
merged_df_LyECs = merged_df_LyECs.merge(Deseq2_LyECs_72, on='Gene', how='outer')

merged_df_Midzonal_LSECs = Deseq2_Midzonal_LSECs_2.merge(Deseq2_Midzonal_LSECs_4, on='Gene', how='outer')
merged_df_Midzonal_LSECs = merged_df_Midzonal_LSECs.merge(Deseq2_Midzonal_LSECs_8, on='Gene', how='outer')
merged_df_Midzonal_LSECs = merged_df_Midzonal_LSECs.merge(Deseq2_Midzonal_LSECs_12, on='Gene', how='outer')
merged_df_Midzonal_LSECs = merged_df_Midzonal_LSECs.merge(Deseq2_Midzonal_LSECs_18, on='Gene', how='outer')
merged_df_Midzonal_LSECs = merged_df_Midzonal_LSECs.merge(Deseq2_Midzonal_LSECs_24, on='Gene', how='outer')
merged_df_Midzonal_LSECs = merged_df_Midzonal_LSECs.merge(Deseq2_Midzonal_LSECs_72, on='Gene', how='outer')

merged_df_PECs = Deseq2_PECs_2.merge(Deseq2_PECs_4, on='Gene', how='outer')
merged_df_PECs = merged_df_PECs.merge(Deseq2_PECs_8, on='Gene', how='outer')
merged_df_PECs = merged_df_PECs.merge(Deseq2_PECs_12, on='Gene', how='outer')
merged_df_PECs = merged_df_PECs.merge(Deseq2_PECs_18, on='Gene', how='outer')
merged_df_PECs = merged_df_PECs.merge(Deseq2_PECs_24, on='Gene', how='outer')
merged_df_PECs = merged_df_PECs.merge(Deseq2_PECs_72, on='Gene', how='outer')

merged_df_Pericentral_LSECs = Deseq2_Pericentral_LSECs_2.merge(Deseq2_Pericentral_LSECs_4, on='Gene', how='outer')
merged_df_Pericentral_LSECs = merged_df_Pericentral_LSECs.merge(Deseq2_Pericentral_LSECs_8, on='Gene', how='outer')
merged_df_Pericentral_LSECs = merged_df_Pericentral_LSECs.merge(Deseq2_Pericentral_LSECs_12, on='Gene', how='outer')
merged_df_Pericentral_LSECs = merged_df_Pericentral_LSECs.merge(Deseq2_Pericentral_LSECs_18, on='Gene', how='outer')
merged_df_Pericentral_LSECs = merged_df_Pericentral_LSECs.merge(Deseq2_Pericentral_LSECs_24, on='Gene', how='outer')
merged_df_Pericentral_LSECs = merged_df_Pericentral_LSECs.merge(Deseq2_Pericentral_LSECs_72, on='Gene', how='outer')

merged_df_Pericentral_VECs = Deseq2_Pericentral_VECs_2.merge(Deseq2_Pericentral_VECs_4, on='Gene', how='outer')
merged_df_Pericentral_VECs = merged_df_Pericentral_VECs.merge(Deseq2_Pericentral_VECs_8, on='Gene', how='outer')
merged_df_Pericentral_VECs = merged_df_Pericentral_VECs.merge(Deseq2_Pericentral_VECs_12, on='Gene', how='outer')
merged_df_Pericentral_VECs = merged_df_Pericentral_VECs.merge(Deseq2_Pericentral_VECs_18, on='Gene', how='outer')
merged_df_Pericentral_VECs = merged_df_Pericentral_VECs.merge(Deseq2_Pericentral_VECs_24, on='Gene', how='outer')
merged_df_Pericentral_VECs = merged_df_Pericentral_VECs.merge(Deseq2_Pericentral_VECs_72, on='Gene', how='outer')

merged_df_Periportal_LSECs = Deseq2_Periportal_LSECs_2.merge(Deseq2_Periportal_LSECs_4, on='Gene', how='outer')
merged_df_Periportal_LSECs = merged_df_Periportal_LSECs.merge(Deseq2_Periportal_LSECs_8, on='Gene', how='outer')
merged_df_Periportal_LSECs = merged_df_Periportal_LSECs.merge(Deseq2_Periportal_LSECs_12, on='Gene', how='outer')
merged_df_Periportal_LSECs = merged_df_Periportal_LSECs.merge(Deseq2_Periportal_LSECs_18, on='Gene', how='outer')
merged_df_Periportal_LSECs = merged_df_Periportal_LSECs.merge(Deseq2_Periportal_LSECs_24, on='Gene', how='outer')
merged_df_Periportal_LSECs = merged_df_Periportal_LSECs.merge(Deseq2_Periportal_LSECs_72, on='Gene', how='outer')

merged_df_Periportal_VECs = Deseq2_Periportal_VECs_2.merge(Deseq2_Periportal_VECs_4, on='Gene', how='outer')
merged_df_Periportal_VECs = merged_df_Periportal_VECs.merge(Deseq2_Periportal_VECs_8, on='Gene', how='outer')
merged_df_Periportal_VECs = merged_df_Periportal_VECs.merge(Deseq2_Periportal_VECs_12, on='Gene', how='outer')
merged_df_Periportal_VECs = merged_df_Periportal_VECs.merge(Deseq2_Periportal_VECs_18, on='Gene', how='outer')
merged_df_Periportal_VECs = merged_df_Periportal_VECs.merge(Deseq2_Periportal_VECs_24, on='Gene', how='outer')
merged_df_Periportal_VECs = merged_df_Periportal_VECs.merge(Deseq2_Periportal_VECs_72, on='Gene', how='outer')

merged_df_Unknown = Deseq2_Unknown_2.merge(Deseq2_Unknown_4, on='Gene', how='outer')
merged_df_Unknown = merged_df_Unknown.merge(Deseq2_Unknown_8, on='Gene', how='outer')
merged_df_Unknown = merged_df_Unknown.merge(Deseq2_Unknown_12, on='Gene', how='outer')
merged_df_Unknown = merged_df_Unknown.merge(Deseq2_Unknown_18, on='Gene', how='outer')
merged_df_Unknown = merged_df_Unknown.merge(Deseq2_Unknown_24, on='Gene', how='outer')
merged_df_Unknown = merged_df_Unknown.merge(Deseq2_Unknown_72, on='Gene', how='outer')

# %%
merged_df_Unknown
# Out:
#          Gene   baseMean_2  log2FoldChange_2   lfcSE_2  FoldChange_2  padj_2
# 0     Gm42418  1401.041965          0.377425  0.572969      1.299021     1.0  \
# 1      Malat1   464.665504         -0.149799  0.229164      0.901376     1.0
# 2       Cmss1   220.186902          0.378536  0.575925      1.300022     1.0
# 3       Stab2    92.578009          0.046626  0.358083      1.032846     1.0
# 4      Camk1d    94.325293          0.539577  0.417650      1.453546     1.0
# ...       ...          ...               ...       ...           ...     ...
# 4439   Ubxn2a     1.071625          0.794058  1.602181      1.733945     1.0
# 4440    Utp11     0.892990         -1.115753  1.749652      0.461450     1.0
# 4441    Vdac1     0.842426          0.000000  1.949133      1.000000     1.0
# 4442    Wdfy1     0.964786         -0.770895  1.774159      0.586054     1.0
# 4443   Zfp746     1.084743          0.887865  1.576758      1.850436     1.0
#
# ...

# %%
merged_df_LyECs.to_csv('./Results/Deseq2_LyECs_Merged.txt', sep='\t')
merged_df_Midzonal_LSECs.to_csv('./Results/Deseq2_Midzonal_LSECs_Merged.txt', sep='\t')
merged_df_PECs.to_csv('./Results/Deseq2_PECs_Merged.txt', sep='\t')
merged_df_Pericentral_LSECs.to_csv('./Results/Deseq2_Pericentral_LSECs_Merged.txt', sep='\t')
merged_df_Pericentral_VECs.to_csv('./Results/Deseq2_Pericentral_VECs_Merged.txt', sep='\t')
merged_df_Periportal_LSECs.to_csv('./Results/Deseq2_Periportal_LSECs_Merged.txt', sep='\t')
merged_df_Periportal_VECs.to_csv('./Results/Deseq2_Periportal_VECs_Merged.txt', sep='\t')
merged_df_Unknown.to_csv('./Results/Deseq2_Unknown_Merged.txt', sep='\t')
