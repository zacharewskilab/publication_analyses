# %% [markdown]
# # Export Desq2 Results for Excel

# %% [markdown]
# ### 1. Import Required Packages
# ### 2. Import Data
# ### 3. Concat All Data Into One Dataframe

# %% [markdown]
# ## <br> 1. Import Required Packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# Set figure parameters.

# %%
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}
# %config InlineBackend.figure_format='retina'
pd.options.display.max_colwidth = 200
#plt.rcParams['font.sans-serif']=['Arial']
plt.rcParams['pdf.fonttype'] = 'truetype'

# %% [markdown]
# ## <br> 2. Import Deseq2 Data

# %%
Deseq2_B_Cell_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/B_Cells_2.txt', delimiter = '\t').reset_index()
Deseq2_B_Cell_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/B_Cells_4.txt', delimiter = '\t').reset_index()
Deseq2_B_Cell_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/B_Cells_8.txt', delimiter = '\t').reset_index()
Deseq2_B_Cell_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/B_Cells_12.txt', delimiter = '\t').reset_index()
Deseq2_B_Cell_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/B_Cells_18.txt', delimiter = '\t').reset_index()
Deseq2_B_Cell_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/B_Cells_24.txt', delimiter = '\t').reset_index()
Deseq2_B_Cell_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/B_Cells_72.txt', delimiter = '\t').reset_index()
Deseq2_Cholangiocyte_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Cholangiocytes_2.txt', delimiter = '\t').reset_index()
Deseq2_Cholangiocyte_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Cholangiocytes_4.txt', delimiter = '\t').reset_index()
Deseq2_Cholangiocyte_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Cholangiocytes_8.txt', delimiter = '\t').reset_index()
Deseq2_Cholangiocyte_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Cholangiocytes_12.txt', delimiter = '\t').reset_index()
Deseq2_Cholangiocyte_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Cholangiocytes_18.txt', delimiter = '\t').reset_index()
Deseq2_Cholangiocyte_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Cholangiocytes_24.txt', delimiter = '\t').reset_index()
Deseq2_Cholangiocyte_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Cholangiocytes_72.txt', delimiter = '\t').reset_index()
Deseq2_Hepatocyte_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Hepatocytes_2.txt', delimiter = '\t').reset_index()
Deseq2_Hepatocyte_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Hepatocytes_4.txt', delimiter = '\t').reset_index()
Deseq2_Hepatocyte_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Hepatocytes_8.txt', delimiter = '\t').reset_index()
Deseq2_Hepatocyte_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Hepatocytes_12.txt', delimiter = '\t').reset_index()
Deseq2_Hepatocyte_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Hepatocytes_18.txt', delimiter = '\t').reset_index()
Deseq2_Hepatocyte_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Hepatocytes_24.txt', delimiter = '\t').reset_index()
Deseq2_Hepatocyte_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Hepatocytes_72.txt', delimiter = '\t').reset_index()
Deseq2_HSC_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/HSCs_2.txt', delimiter = '\t').reset_index()
Deseq2_HSC_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/HSCs_4.txt', delimiter = '\t').reset_index()
Deseq2_HSC_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/HSCs_8.txt', delimiter = '\t').reset_index()
Deseq2_HSC_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/HSCs_12.txt', delimiter = '\t').reset_index()
Deseq2_HSC_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/HSCs_18.txt', delimiter = '\t').reset_index()
Deseq2_HSC_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/HSCs_24.txt', delimiter = '\t').reset_index()
Deseq2_HSC_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/HSCs_72.txt', delimiter = '\t').reset_index()
Deseq2_EC_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/ECs_2.txt', delimiter = '\t').reset_index()
Deseq2_EC_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/ECs_4.txt', delimiter = '\t').reset_index()
Deseq2_EC_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/ECs_8.txt', delimiter = '\t').reset_index()
Deseq2_EC_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/ECs_12.txt', delimiter = '\t').reset_index()
Deseq2_EC_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/ECs_18.txt', delimiter = '\t').reset_index()
Deseq2_EC_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/ECs_24.txt', delimiter = '\t').reset_index()
Deseq2_EC_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/ECs_72.txt', delimiter = '\t').reset_index()
Deseq2_Macrophage_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Macrophages_2.txt', delimiter = '\t').reset_index()
Deseq2_Macrophage_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Macrophages_4.txt', delimiter = '\t').reset_index()
Deseq2_Macrophage_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Macrophages_8.txt', delimiter = '\t').reset_index()
Deseq2_Macrophage_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Macrophages_12.txt', delimiter = '\t').reset_index()
Deseq2_Macrophage_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Macrophages_18.txt', delimiter = '\t').reset_index()
Deseq2_Macrophage_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Macrophages_24.txt', delimiter = '\t').reset_index()
Deseq2_Macrophage_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Macrophages_72.txt', delimiter = '\t').reset_index()
Deseq2_Neutrophil_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Neutrophils_2.txt', delimiter = '\t').reset_index()
Deseq2_Neutrophil_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Neutrophils_4.txt', delimiter = '\t').reset_index()
Deseq2_Neutrophil_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Neutrophils_8.txt', delimiter = '\t').reset_index()
Deseq2_Neutrophil_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Neutrophils_12.txt', delimiter = '\t').reset_index()
Deseq2_Neutrophil_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Neutrophils_18.txt', delimiter = '\t').reset_index()
Deseq2_Neutrophil_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Neutrophils_24.txt', delimiter = '\t').reset_index()
Deseq2_Neutrophil_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/Neutrophils_72.txt', delimiter = '\t').reset_index()
Deseq2_pDC_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/pDCs_2.txt', delimiter = '\t').reset_index()
Deseq2_pDC_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/pDCs_4.txt', delimiter = '\t').reset_index()
Deseq2_pDC_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/pDCs_8.txt', delimiter = '\t').reset_index()
Deseq2_pDC_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/pDCs_12.txt', delimiter = '\t').reset_index()
Deseq2_pDC_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/pDCs_18.txt', delimiter = '\t').reset_index()
Deseq2_pDC_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/pDCs_24.txt', delimiter = '\t').reset_index()
Deseq2_pDC_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/pDCs_72.txt', delimiter = '\t').reset_index()
Deseq2_PF_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/PFs_2.txt', delimiter = '\t').reset_index()
Deseq2_PF_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/PFs_4.txt', delimiter = '\t').reset_index()
Deseq2_PF_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/PFs_8.txt', delimiter = '\t').reset_index()
Deseq2_PF_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/PFs_12.txt', delimiter = '\t').reset_index()
Deseq2_PF_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/PFs_18.txt', delimiter = '\t').reset_index()
Deseq2_PF_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/PFs_24.txt', delimiter = '\t').reset_index()
Deseq2_PF_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/PFs_72.txt', delimiter = '\t').reset_index()
Deseq2_T_Cell_2 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/T_Cells_2.txt', delimiter = '\t').reset_index()
Deseq2_T_Cell_4 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/T_Cells_4.txt', delimiter = '\t').reset_index()
Deseq2_T_Cell_8 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/T_Cells_8.txt', delimiter = '\t').reset_index()
Deseq2_T_Cell_12 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/T_Cells_12.txt', delimiter = '\t').reset_index()
Deseq2_T_Cell_18 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/T_Cells_18.txt', delimiter = '\t').reset_index()
Deseq2_T_Cell_24 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/T_Cells_24.txt', delimiter = '\t').reset_index()
Deseq2_T_Cell_72 = pd.read_csv('../03_Differential_Gene_Expression_Analysis---Deseq2/Results/T_Cells_72.txt', delimiter = '\t').reset_index()

# %%
Deseq2_B_Cell_2['FoldChange'] = 2 ** Deseq2_B_Cell_2['log2FoldChange']
Deseq2_B_Cell_4['FoldChange'] = 2 ** Deseq2_B_Cell_4['log2FoldChange']
Deseq2_B_Cell_8['FoldChange'] = 2 ** Deseq2_B_Cell_8['log2FoldChange']
Deseq2_B_Cell_12['FoldChange'] = 2 ** Deseq2_B_Cell_12['log2FoldChange']
Deseq2_B_Cell_18['FoldChange'] = 2 ** Deseq2_B_Cell_18['log2FoldChange']
Deseq2_B_Cell_24['FoldChange'] = 2 ** Deseq2_B_Cell_24['log2FoldChange']
Deseq2_B_Cell_72['FoldChange'] = 2 ** Deseq2_B_Cell_72['log2FoldChange']
Deseq2_Cholangiocyte_2['FoldChange'] = 2 ** Deseq2_Cholangiocyte_2['log2FoldChange']
Deseq2_Cholangiocyte_4['FoldChange'] = 2 ** Deseq2_Cholangiocyte_4['log2FoldChange']
Deseq2_Cholangiocyte_8['FoldChange'] = 2 ** Deseq2_Cholangiocyte_8['log2FoldChange']
Deseq2_Cholangiocyte_12['FoldChange'] = 2 ** Deseq2_Cholangiocyte_12['log2FoldChange']
Deseq2_Cholangiocyte_18['FoldChange'] = 2 ** Deseq2_Cholangiocyte_18['log2FoldChange']
Deseq2_Cholangiocyte_24['FoldChange'] = 2 ** Deseq2_Cholangiocyte_24['log2FoldChange']
Deseq2_Cholangiocyte_72['FoldChange'] = 2 ** Deseq2_Cholangiocyte_72['log2FoldChange']
Deseq2_EC_2['FoldChange'] = 2 ** Deseq2_EC_2['log2FoldChange']
Deseq2_EC_4['FoldChange'] = 2 ** Deseq2_EC_4['log2FoldChange']
Deseq2_EC_8['FoldChange'] = 2 ** Deseq2_EC_8['log2FoldChange']
Deseq2_EC_12['FoldChange'] = 2 ** Deseq2_EC_12['log2FoldChange']
Deseq2_EC_18['FoldChange'] = 2 ** Deseq2_EC_18['log2FoldChange']
Deseq2_EC_24['FoldChange'] = 2 ** Deseq2_EC_24['log2FoldChange']
Deseq2_EC_72['FoldChange'] = 2 ** Deseq2_EC_72['log2FoldChange']
Deseq2_Hepatocyte_2['FoldChange'] = 2 ** Deseq2_Hepatocyte_2['log2FoldChange']
Deseq2_Hepatocyte_4['FoldChange'] = 2 ** Deseq2_Hepatocyte_4['log2FoldChange']
Deseq2_Hepatocyte_8['FoldChange'] = 2 ** Deseq2_Hepatocyte_8['log2FoldChange']
Deseq2_Hepatocyte_12['FoldChange'] = 2 ** Deseq2_Hepatocyte_12['log2FoldChange']
Deseq2_Hepatocyte_18['FoldChange'] = 2 ** Deseq2_Hepatocyte_18['log2FoldChange']
Deseq2_Hepatocyte_24['FoldChange'] = 2 ** Deseq2_Hepatocyte_24['log2FoldChange']
Deseq2_Hepatocyte_72['FoldChange'] = 2 ** Deseq2_Hepatocyte_72['log2FoldChange']
Deseq2_HSC_2['FoldChange'] = 2 ** Deseq2_HSC_2['log2FoldChange']
Deseq2_HSC_4['FoldChange'] = 2 ** Deseq2_HSC_4['log2FoldChange']
Deseq2_HSC_8['FoldChange'] = 2 ** Deseq2_HSC_8['log2FoldChange']
Deseq2_HSC_12['FoldChange'] = 2 ** Deseq2_HSC_12['log2FoldChange']
Deseq2_HSC_18['FoldChange'] = 2 ** Deseq2_HSC_18['log2FoldChange']
Deseq2_HSC_24['FoldChange'] = 2 ** Deseq2_HSC_24['log2FoldChange']
Deseq2_HSC_72['FoldChange'] = 2 ** Deseq2_HSC_72['log2FoldChange']
Deseq2_Macrophage_2['FoldChange'] = 2 ** Deseq2_Macrophage_2['log2FoldChange']
Deseq2_Macrophage_4['FoldChange'] = 2 ** Deseq2_Macrophage_4['log2FoldChange']
Deseq2_Macrophage_8['FoldChange'] = 2 ** Deseq2_Macrophage_8['log2FoldChange']
Deseq2_Macrophage_12['FoldChange'] = 2 ** Deseq2_Macrophage_12['log2FoldChange']
Deseq2_Macrophage_18['FoldChange'] = 2 ** Deseq2_Macrophage_18['log2FoldChange']
Deseq2_Macrophage_24['FoldChange'] = 2 ** Deseq2_Macrophage_24['log2FoldChange']
Deseq2_Macrophage_72['FoldChange'] = 2 ** Deseq2_Macrophage_72['log2FoldChange']
Deseq2_Neutrophil_2['FoldChange'] = 2 ** Deseq2_Neutrophil_2['log2FoldChange']
Deseq2_Neutrophil_4['FoldChange'] = 2 ** Deseq2_Neutrophil_4['log2FoldChange']
Deseq2_Neutrophil_8['FoldChange'] = 2 ** Deseq2_Neutrophil_8['log2FoldChange']
Deseq2_Neutrophil_12['FoldChange'] = 2 ** Deseq2_Neutrophil_12['log2FoldChange']
Deseq2_Neutrophil_18['FoldChange'] = 2 ** Deseq2_Neutrophil_18['log2FoldChange']
Deseq2_Neutrophil_24['FoldChange'] = 2 ** Deseq2_Neutrophil_24['log2FoldChange']
Deseq2_Neutrophil_72['FoldChange'] = 2 ** Deseq2_Neutrophil_72['log2FoldChange']
Deseq2_pDC_2['FoldChange'] = 2 ** Deseq2_pDC_2['log2FoldChange']
Deseq2_pDC_4['FoldChange'] = 2 ** Deseq2_pDC_4['log2FoldChange']
Deseq2_pDC_8['FoldChange'] = 2 ** Deseq2_pDC_8['log2FoldChange']
Deseq2_pDC_12['FoldChange'] = 2 ** Deseq2_pDC_12['log2FoldChange']
Deseq2_pDC_18['FoldChange'] = 2 ** Deseq2_pDC_18['log2FoldChange']
Deseq2_pDC_24['FoldChange'] = 2 ** Deseq2_pDC_24['log2FoldChange']
Deseq2_pDC_72['FoldChange'] = 2 ** Deseq2_pDC_72['log2FoldChange']
Deseq2_PF_2['FoldChange'] = 2 ** Deseq2_PF_2['log2FoldChange']
Deseq2_PF_4['FoldChange'] = 2 ** Deseq2_PF_4['log2FoldChange']
Deseq2_PF_8['FoldChange'] = 2 ** Deseq2_PF_8['log2FoldChange']
Deseq2_PF_12['FoldChange'] = 2 ** Deseq2_PF_12['log2FoldChange']
Deseq2_PF_18['FoldChange'] = 2 ** Deseq2_PF_18['log2FoldChange']
Deseq2_PF_24['FoldChange'] = 2 ** Deseq2_PF_24['log2FoldChange']
Deseq2_PF_72['FoldChange'] = 2 ** Deseq2_PF_72['log2FoldChange']
Deseq2_T_Cell_2['FoldChange'] = 2 ** Deseq2_T_Cell_2['log2FoldChange']
Deseq2_T_Cell_4['FoldChange'] = 2 ** Deseq2_T_Cell_4['log2FoldChange']
Deseq2_T_Cell_8['FoldChange'] = 2 ** Deseq2_T_Cell_8['log2FoldChange']
Deseq2_T_Cell_12['FoldChange'] = 2 ** Deseq2_T_Cell_12['log2FoldChange']
Deseq2_T_Cell_18['FoldChange'] = 2 ** Deseq2_T_Cell_18['log2FoldChange']
Deseq2_T_Cell_24['FoldChange'] = 2 ** Deseq2_T_Cell_24['log2FoldChange']
Deseq2_T_Cell_72['FoldChange'] = 2 ** Deseq2_T_Cell_72['log2FoldChange']

# %%
Deseq2_B_Cell_2=Deseq2_B_Cell_2.rename(columns={'index': 'Gene'})
Deseq2_B_Cell_4=Deseq2_B_Cell_4.rename(columns={'index': 'Gene'})
Deseq2_B_Cell_8=Deseq2_B_Cell_8.rename(columns={'index': 'Gene'})
Deseq2_B_Cell_12=Deseq2_B_Cell_12.rename(columns={'index': 'Gene'})
Deseq2_B_Cell_18=Deseq2_B_Cell_18.rename(columns={'index': 'Gene'})
Deseq2_B_Cell_24=Deseq2_B_Cell_24.rename(columns={'index': 'Gene'})
Deseq2_B_Cell_72=Deseq2_B_Cell_72.rename(columns={'index': 'Gene'})
Deseq2_Cholangiocyte_2=Deseq2_Cholangiocyte_2.rename(columns={'index': 'Gene'})
Deseq2_Cholangiocyte_4=Deseq2_Cholangiocyte_4.rename(columns={'index': 'Gene'})
Deseq2_Cholangiocyte_8=Deseq2_Cholangiocyte_8.rename(columns={'index': 'Gene'})
Deseq2_Cholangiocyte_12=Deseq2_Cholangiocyte_12.rename(columns={'index': 'Gene'})
Deseq2_Cholangiocyte_18=Deseq2_Cholangiocyte_18.rename(columns={'index': 'Gene'})
Deseq2_Cholangiocyte_24=Deseq2_Cholangiocyte_24.rename(columns={'index': 'Gene'})
Deseq2_Cholangiocyte_72=Deseq2_Cholangiocyte_72.rename(columns={'index': 'Gene'})
Deseq2_EC_2=Deseq2_EC_2.rename(columns={'index': 'Gene'})
Deseq2_EC_4=Deseq2_EC_4.rename(columns={'index': 'Gene'})
Deseq2_EC_8=Deseq2_EC_8.rename(columns={'index': 'Gene'})
Deseq2_EC_12=Deseq2_EC_12.rename(columns={'index': 'Gene'})
Deseq2_EC_18=Deseq2_EC_18.rename(columns={'index': 'Gene'})
Deseq2_EC_24=Deseq2_EC_24.rename(columns={'index': 'Gene'})
Deseq2_EC_72=Deseq2_EC_72.rename(columns={'index': 'Gene'})
Deseq2_Hepatocyte_2=Deseq2_Hepatocyte_2.rename(columns={'index': 'Gene'})
Deseq2_Hepatocyte_4=Deseq2_Hepatocyte_4.rename(columns={'index': 'Gene'})
Deseq2_Hepatocyte_8=Deseq2_Hepatocyte_8.rename(columns={'index': 'Gene'})
Deseq2_Hepatocyte_12=Deseq2_Hepatocyte_12.rename(columns={'index': 'Gene'})
Deseq2_Hepatocyte_18=Deseq2_Hepatocyte_18.rename(columns={'index': 'Gene'})
Deseq2_Hepatocyte_24=Deseq2_Hepatocyte_24.rename(columns={'index': 'Gene'})
Deseq2_Hepatocyte_72=Deseq2_Hepatocyte_72.rename(columns={'index': 'Gene'})
Deseq2_HSC_2=Deseq2_HSC_2.rename(columns={'index': 'Gene'})
Deseq2_HSC_4=Deseq2_HSC_4.rename(columns={'index': 'Gene'})
Deseq2_HSC_8=Deseq2_HSC_8.rename(columns={'index': 'Gene'})
Deseq2_HSC_12=Deseq2_HSC_12.rename(columns={'index': 'Gene'})
Deseq2_HSC_18=Deseq2_HSC_18.rename(columns={'index': 'Gene'})
Deseq2_HSC_24=Deseq2_HSC_24.rename(columns={'index': 'Gene'})
Deseq2_HSC_72=Deseq2_HSC_72.rename(columns={'index': 'Gene'})
Deseq2_Macrophage_2=Deseq2_Macrophage_2.rename(columns={'index': 'Gene'})
Deseq2_Macrophage_4=Deseq2_Macrophage_4.rename(columns={'index': 'Gene'})
Deseq2_Macrophage_8=Deseq2_Macrophage_8.rename(columns={'index': 'Gene'})
Deseq2_Macrophage_12=Deseq2_Macrophage_12.rename(columns={'index': 'Gene'})
Deseq2_Macrophage_18=Deseq2_Macrophage_18.rename(columns={'index': 'Gene'})
Deseq2_Macrophage_24=Deseq2_Macrophage_24.rename(columns={'index': 'Gene'})
Deseq2_Macrophage_72=Deseq2_Macrophage_72.rename(columns={'index': 'Gene'})
Deseq2_Neutrophil_2=Deseq2_Neutrophil_2.rename(columns={'index': 'Gene'})
Deseq2_Neutrophil_4=Deseq2_Neutrophil_4.rename(columns={'index': 'Gene'})
Deseq2_Neutrophil_8=Deseq2_Neutrophil_8.rename(columns={'index': 'Gene'})
Deseq2_Neutrophil_12=Deseq2_Neutrophil_12.rename(columns={'index': 'Gene'})
Deseq2_Neutrophil_18=Deseq2_Neutrophil_18.rename(columns={'index': 'Gene'})
Deseq2_Neutrophil_24=Deseq2_Neutrophil_24.rename(columns={'index': 'Gene'})
Deseq2_Neutrophil_72=Deseq2_Neutrophil_72.rename(columns={'index': 'Gene'})
Deseq2_pDC_2=Deseq2_pDC_2.rename(columns={'index': 'Gene'})
Deseq2_pDC_4=Deseq2_pDC_4.rename(columns={'index': 'Gene'})
Deseq2_pDC_8=Deseq2_pDC_8.rename(columns={'index': 'Gene'})
Deseq2_pDC_12=Deseq2_pDC_12.rename(columns={'index': 'Gene'})
Deseq2_pDC_18=Deseq2_pDC_18.rename(columns={'index': 'Gene'})
Deseq2_pDC_24=Deseq2_pDC_24.rename(columns={'index': 'Gene'})
Deseq2_pDC_72=Deseq2_pDC_72.rename(columns={'index': 'Gene'})
Deseq2_PF_2=Deseq2_PF_2.rename(columns={'index': 'Gene'})
Deseq2_PF_4=Deseq2_PF_4.rename(columns={'index': 'Gene'})
Deseq2_PF_8=Deseq2_PF_8.rename(columns={'index': 'Gene'})
Deseq2_PF_12=Deseq2_PF_12.rename(columns={'index': 'Gene'})
Deseq2_PF_18=Deseq2_PF_18.rename(columns={'index': 'Gene'})
Deseq2_PF_24=Deseq2_PF_24.rename(columns={'index': 'Gene'})
Deseq2_PF_72=Deseq2_PF_72.rename(columns={'index': 'Gene'})
Deseq2_T_Cell_2=Deseq2_T_Cell_2.rename(columns={'index': 'Gene'})
Deseq2_T_Cell_4=Deseq2_T_Cell_4.rename(columns={'index': 'Gene'})
Deseq2_T_Cell_8=Deseq2_T_Cell_8.rename(columns={'index': 'Gene'})
Deseq2_T_Cell_12=Deseq2_T_Cell_12.rename(columns={'index': 'Gene'})
Deseq2_T_Cell_18=Deseq2_T_Cell_18.rename(columns={'index': 'Gene'})
Deseq2_T_Cell_24=Deseq2_T_Cell_24.rename(columns={'index': 'Gene'})
Deseq2_T_Cell_72=Deseq2_T_Cell_72.rename(columns={'index': 'Gene'})

# %%
Deseq2_T_Cell_72
# Out:
#          Gene      baseMean  log2FoldChange     lfcSE      stat    pvalue
# 0     Gm42418  11581.277851       -0.532661  0.471728 -1.129169  0.258827  \
# 1      Malat1   4339.066500        0.216765  0.178402  1.215037  0.224352
# 2       Cmss1   1843.015847       -0.355469  0.469587 -0.756982  0.449061
# 3      Camk1d    859.051926       -0.125539  0.278448 -0.450853  0.652095
# 4        Gphn    689.939060       -0.258055  0.337342 -0.764966  0.444292
# ...       ...           ...             ...       ...       ...       ...
# 9528     Tfpi      1.631608       -0.321517  1.136329 -0.282943  0.777220
# 9529  Tmem128      1.647822       -1.621279  1.074936 -1.508257  0.131489
# 9530     Wbp1      1.682889       -0.317524  1.098354 -0.289091  0.772512
# 9531   Zfp324      1.478046       -0.332261  1.205061 -0.275721  0.782762
# 9532   Zfp791      1.556305       -1.550694  1.246690 -1.243849  0.213555
#
#           padj  FoldChange
# 0     0.999076    0.691279
# ...

# %%
Deseq2_B_Cell_2=Deseq2_B_Cell_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_B_Cell_4=Deseq2_B_Cell_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_B_Cell_8=Deseq2_B_Cell_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_B_Cell_12=Deseq2_B_Cell_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_B_Cell_18=Deseq2_B_Cell_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_B_Cell_24=Deseq2_B_Cell_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_B_Cell_72=Deseq2_B_Cell_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Cholangiocyte_2=Deseq2_Cholangiocyte_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Cholangiocyte_4=Deseq2_Cholangiocyte_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Cholangiocyte_8=Deseq2_Cholangiocyte_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Cholangiocyte_12=Deseq2_Cholangiocyte_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Cholangiocyte_18=Deseq2_Cholangiocyte_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Cholangiocyte_24=Deseq2_Cholangiocyte_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Cholangiocyte_72=Deseq2_Cholangiocyte_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_EC_2=Deseq2_EC_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_EC_4=Deseq2_EC_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_EC_8=Deseq2_EC_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_EC_12=Deseq2_EC_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_EC_18=Deseq2_EC_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_EC_24=Deseq2_EC_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_EC_72=Deseq2_EC_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Hepatocyte_2=Deseq2_Hepatocyte_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Hepatocyte_4=Deseq2_Hepatocyte_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Hepatocyte_8=Deseq2_Hepatocyte_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Hepatocyte_12=Deseq2_Hepatocyte_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Hepatocyte_18=Deseq2_Hepatocyte_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Hepatocyte_24=Deseq2_Hepatocyte_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Hepatocyte_72=Deseq2_Hepatocyte_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_HSC_2=Deseq2_HSC_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_HSC_4=Deseq2_HSC_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_HSC_8=Deseq2_HSC_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_HSC_12=Deseq2_HSC_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_HSC_18=Deseq2_HSC_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_HSC_24=Deseq2_HSC_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_HSC_72=Deseq2_HSC_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Macrophage_2=Deseq2_Macrophage_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Macrophage_4=Deseq2_Macrophage_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Macrophage_8=Deseq2_Macrophage_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Macrophage_12=Deseq2_Macrophage_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Macrophage_18=Deseq2_Macrophage_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Macrophage_24=Deseq2_Macrophage_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Macrophage_72=Deseq2_Macrophage_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Neutrophil_2=Deseq2_Neutrophil_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Neutrophil_4=Deseq2_Neutrophil_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Neutrophil_8=Deseq2_Neutrophil_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Neutrophil_12=Deseq2_Neutrophil_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Neutrophil_18=Deseq2_Neutrophil_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Neutrophil_24=Deseq2_Neutrophil_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_Neutrophil_72=Deseq2_Neutrophil_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_pDC_2=Deseq2_pDC_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_pDC_4=Deseq2_pDC_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_pDC_8=Deseq2_pDC_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_pDC_12=Deseq2_pDC_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_pDC_18=Deseq2_pDC_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_pDC_24=Deseq2_pDC_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_pDC_72=Deseq2_pDC_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PF_2=Deseq2_PF_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PF_4=Deseq2_PF_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PF_8=Deseq2_PF_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PF_12=Deseq2_PF_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PF_18=Deseq2_PF_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PF_24=Deseq2_PF_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_PF_72=Deseq2_PF_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_T_Cell_2=Deseq2_T_Cell_2[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_T_Cell_4=Deseq2_T_Cell_4[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_T_Cell_8=Deseq2_T_Cell_8[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_T_Cell_12=Deseq2_T_Cell_12[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_T_Cell_18=Deseq2_T_Cell_18[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_T_Cell_24=Deseq2_T_Cell_24[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]
Deseq2_T_Cell_72=Deseq2_T_Cell_72[['Gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'FoldChange', 'padj']]

# %%
Deseq2_Hepatocyte_12[Deseq2_Hepatocyte_12['Gene'] == 'Xlr4a']
# Out:
#         Gene   baseMean  log2FoldChange     lfcSE  FoldChange      padj
# 14565  Xlr4a  11.669872        0.510628  2.218654     1.42467  0.913873

# %%
Deseq2_B_Cell_2=Deseq2_B_Cell_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_B_Cell_4=Deseq2_B_Cell_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_B_Cell_8=Deseq2_B_Cell_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_B_Cell_12=Deseq2_B_Cell_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_B_Cell_18=Deseq2_B_Cell_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_B_Cell_24=Deseq2_B_Cell_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_B_Cell_72=Deseq2_B_Cell_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_Cholangiocyte_2=Deseq2_Cholangiocyte_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_Cholangiocyte_4=Deseq2_Cholangiocyte_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_Cholangiocyte_8=Deseq2_Cholangiocyte_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_Cholangiocyte_12=Deseq2_Cholangiocyte_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_Cholangiocyte_18=Deseq2_Cholangiocyte_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_Cholangiocyte_24=Deseq2_Cholangiocyte_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_Cholangiocyte_72=Deseq2_Cholangiocyte_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_EC_2=Deseq2_EC_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_EC_4=Deseq2_EC_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_EC_8=Deseq2_EC_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_EC_12=Deseq2_EC_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_EC_18=Deseq2_EC_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_EC_24=Deseq2_EC_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_EC_72=Deseq2_EC_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_Hepatocyte_2=Deseq2_Hepatocyte_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_Hepatocyte_4=Deseq2_Hepatocyte_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_Hepatocyte_8=Deseq2_Hepatocyte_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_Hepatocyte_12=Deseq2_Hepatocyte_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_Hepatocyte_18=Deseq2_Hepatocyte_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_Hepatocyte_24=Deseq2_Hepatocyte_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_Hepatocyte_72=Deseq2_Hepatocyte_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_HSC_2=Deseq2_HSC_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_HSC_4=Deseq2_HSC_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_HSC_8=Deseq2_HSC_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_HSC_12=Deseq2_HSC_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_HSC_18=Deseq2_HSC_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_HSC_24=Deseq2_HSC_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_HSC_72=Deseq2_HSC_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_Macrophage_2=Deseq2_Macrophage_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_Macrophage_4=Deseq2_Macrophage_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_Macrophage_8=Deseq2_Macrophage_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_Macrophage_12=Deseq2_Macrophage_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_Macrophage_18=Deseq2_Macrophage_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_Macrophage_24=Deseq2_Macrophage_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_Macrophage_72=Deseq2_Macrophage_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_Neutrophil_2=Deseq2_Neutrophil_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_Neutrophil_4=Deseq2_Neutrophil_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_Neutrophil_8=Deseq2_Neutrophil_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_Neutrophil_12=Deseq2_Neutrophil_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_Neutrophil_18=Deseq2_Neutrophil_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_Neutrophil_24=Deseq2_Neutrophil_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_Neutrophil_72=Deseq2_Neutrophil_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_pDC_2=Deseq2_pDC_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_pDC_4=Deseq2_pDC_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_pDC_8=Deseq2_pDC_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_pDC_12=Deseq2_pDC_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_pDC_18=Deseq2_pDC_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_pDC_24=Deseq2_pDC_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_pDC_72=Deseq2_pDC_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_PF_2=Deseq2_PF_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_PF_4=Deseq2_PF_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_PF_8=Deseq2_PF_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_PF_12=Deseq2_PF_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_PF_18=Deseq2_PF_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_PF_24=Deseq2_PF_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_PF_72=Deseq2_PF_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})
Deseq2_T_Cell_2=Deseq2_T_Cell_2.rename(columns={'baseMean': 'baseMean_2','lfcSE':'lfcSE_2',  'log2FoldChange': 'log2FoldChange_2','padj': 'padj_2', 'FoldChange':'FoldChange_2'})
Deseq2_T_Cell_4=Deseq2_T_Cell_4.rename(columns={'baseMean': 'baseMean_4','lfcSE':'lfcSE_4',  'log2FoldChange': 'log2FoldChange_4',  'padj': 'padj_4', 'FoldChange':'FoldChange_4'})
Deseq2_T_Cell_8=Deseq2_T_Cell_8.rename(columns={'baseMean': 'baseMean_8','lfcSE':'lfcSE_8',  'log2FoldChange': 'log2FoldChange_8', 'padj': 'padj_8', 'FoldChange':'FoldChange_8'})
Deseq2_T_Cell_12=Deseq2_T_Cell_12.rename(columns={'baseMean': 'baseMean_12','lfcSE':'lfcSE_12',  'log2FoldChange': 'log2FoldChange_12', 'padj': 'padj_12', 'FoldChange':'FoldChange_12'})
Deseq2_T_Cell_18=Deseq2_T_Cell_18.rename(columns={'baseMean': 'baseMean_18','lfcSE':'lfcSE_18',  'log2FoldChange': 'log2FoldChange_18', 'padj': 'padj_18', 'FoldChange':'FoldChange_18'})
Deseq2_T_Cell_24=Deseq2_T_Cell_24.rename(columns={'baseMean': 'baseMean_24','lfcSE':'lfcSE_24',  'log2FoldChange': 'log2FoldChange_24', 'padj': 'padj_24', 'FoldChange':'FoldChange_24'})
Deseq2_T_Cell_72=Deseq2_T_Cell_72.rename(columns={'baseMean': 'baseMean_72','lfcSE':'lfcSE_72',  'log2FoldChange': 'log2FoldChange_72', 'padj': 'padj_72', 'FoldChange':'FoldChange_72'})

# %%
Deseq2_B_Cell_2
# Out:
#          Gene   baseMean_2  log2FoldChange_2   lfcSE_2  FoldChange_2    padj_2
# 0     Gm42418  9721.280933          0.090394  0.450800      1.064661  0.998335
# 1      Malat1  3845.002291         -0.101792  0.159584      0.931875  0.998335
# 2       Cmss1  1590.724138          0.309259  0.446208      1.239071  0.998335
# 3       Foxp1   795.056702         -0.041252  0.180903      0.971811  0.998335
# 4      Camk1d   746.328996          0.123394  0.308227      1.089294  0.998335
# ...       ...          ...               ...       ...           ...       ...
# 9123   Tubb4b     1.121671         -2.509371  1.463017      0.175632       NaN
# 9124     Ubl5     1.493169         -1.872974  1.457213      0.273010       NaN
# 9125  Zfp512b     1.364484          0.883871  1.430116      1.845320       NaN
# 9126   Zfp566     1.324555         -0.432129  1.672044      0.741167       NaN
# 9127   Zfp959     1.417925         -0.566650  1.120295      0.675183       NaN
#
# [9128 rows x 6 columns]

# %% [markdown]
# ## <br> 3. Merge All Data Into One Dataframe Fro each Cell

# %%
merged_df_B_Cell = Deseq2_B_Cell_2.merge(Deseq2_B_Cell_4, on='Gene', how='outer')
merged_df_B_Cell = merged_df_B_Cell.merge(Deseq2_B_Cell_8, on='Gene', how='outer')
merged_df_B_Cell = merged_df_B_Cell.merge(Deseq2_B_Cell_12, on='Gene', how='outer')
merged_df_B_Cell = merged_df_B_Cell.merge(Deseq2_B_Cell_18, on='Gene', how='outer')
merged_df_B_Cell = merged_df_B_Cell.merge(Deseq2_B_Cell_24, on='Gene', how='outer')
merged_df_B_Cell = merged_df_B_Cell.merge(Deseq2_B_Cell_72, on='Gene', how='outer')

merged_df_Cholangiocyte = Deseq2_Cholangiocyte_2.merge(Deseq2_Cholangiocyte_4, on='Gene', how='outer')
merged_df_Cholangiocyte = merged_df_Cholangiocyte.merge(Deseq2_Cholangiocyte_8, on='Gene', how='outer')
merged_df_Cholangiocyte = merged_df_Cholangiocyte.merge(Deseq2_Cholangiocyte_12, on='Gene', how='outer')
merged_df_Cholangiocyte = merged_df_Cholangiocyte.merge(Deseq2_Cholangiocyte_18, on='Gene', how='outer')
merged_df_Cholangiocyte = merged_df_Cholangiocyte.merge(Deseq2_Cholangiocyte_24, on='Gene', how='outer')
merged_df_Cholangiocyte = merged_df_Cholangiocyte.merge(Deseq2_Cholangiocyte_72, on='Gene', how='outer')

merged_df_EC = Deseq2_EC_2.merge(Deseq2_EC_4, on='Gene', how='outer')
merged_df_EC = merged_df_EC.merge(Deseq2_EC_8, on='Gene', how='outer')
merged_df_EC = merged_df_EC.merge(Deseq2_EC_12, on='Gene', how='outer')
merged_df_EC = merged_df_EC.merge(Deseq2_EC_18, on='Gene', how='outer')
merged_df_EC = merged_df_EC.merge(Deseq2_EC_24, on='Gene', how='outer')
merged_df_EC = merged_df_EC.merge(Deseq2_EC_72, on='Gene', how='outer')

merged_df_Hepatocyte = Deseq2_Hepatocyte_2.merge(Deseq2_Hepatocyte_4, on='Gene', how='outer')
merged_df_Hepatocyte = merged_df_Hepatocyte.merge(Deseq2_Hepatocyte_8, on='Gene', how='outer')
merged_df_Hepatocyte = merged_df_Hepatocyte.merge(Deseq2_Hepatocyte_12, on='Gene', how='outer')
merged_df_Hepatocyte = merged_df_Hepatocyte.merge(Deseq2_Hepatocyte_18, on='Gene', how='outer')
merged_df_Hepatocyte = merged_df_Hepatocyte.merge(Deseq2_Hepatocyte_24, on='Gene', how='outer')
merged_df_Hepatocyte = merged_df_Hepatocyte.merge(Deseq2_Hepatocyte_72, on='Gene', how='outer')

merged_df_HSC = Deseq2_HSC_2.merge(Deseq2_HSC_4, on='Gene', how='outer')
merged_df_HSC = merged_df_HSC.merge(Deseq2_HSC_8, on='Gene', how='outer')
merged_df_HSC = merged_df_HSC.merge(Deseq2_HSC_12, on='Gene', how='outer')
merged_df_HSC = merged_df_HSC.merge(Deseq2_HSC_18, on='Gene', how='outer')
merged_df_HSC = merged_df_HSC.merge(Deseq2_HSC_24, on='Gene', how='outer')
merged_df_HSC = merged_df_HSC.merge(Deseq2_HSC_72, on='Gene', how='outer')

merged_df_Macrophage = Deseq2_Macrophage_2.merge(Deseq2_Macrophage_4, on='Gene', how='outer')
merged_df_Macrophage = merged_df_Macrophage.merge(Deseq2_Macrophage_8, on='Gene', how='outer')
merged_df_Macrophage = merged_df_Macrophage.merge(Deseq2_Macrophage_12, on='Gene', how='outer')
merged_df_Macrophage = merged_df_Macrophage.merge(Deseq2_Macrophage_18, on='Gene', how='outer')
merged_df_Macrophage = merged_df_Macrophage.merge(Deseq2_Macrophage_24, on='Gene', how='outer')
merged_df_Macrophage = merged_df_Macrophage.merge(Deseq2_Macrophage_72, on='Gene', how='outer')

merged_df_Neutrophil = Deseq2_Neutrophil_2.merge(Deseq2_Neutrophil_4, on='Gene', how='outer')
merged_df_Neutrophil = merged_df_Neutrophil.merge(Deseq2_Neutrophil_8, on='Gene', how='outer')
merged_df_Neutrophil = merged_df_Neutrophil.merge(Deseq2_Neutrophil_12, on='Gene', how='outer')
merged_df_Neutrophil = merged_df_Neutrophil.merge(Deseq2_Neutrophil_18, on='Gene', how='outer')
merged_df_Neutrophil = merged_df_Neutrophil.merge(Deseq2_Neutrophil_24, on='Gene', how='outer')
merged_df_Neutrophil = merged_df_Neutrophil.merge(Deseq2_Neutrophil_72, on='Gene', how='outer')

merged_df_pDC = Deseq2_pDC_2.merge(Deseq2_pDC_4, on='Gene', how='outer')
merged_df_pDC = merged_df_pDC.merge(Deseq2_pDC_8, on='Gene', how='outer')
merged_df_pDC = merged_df_pDC.merge(Deseq2_pDC_12, on='Gene', how='outer')
merged_df_pDC = merged_df_pDC.merge(Deseq2_pDC_18, on='Gene', how='outer')
merged_df_pDC = merged_df_pDC.merge(Deseq2_pDC_24, on='Gene', how='outer')
merged_df_pDC = merged_df_pDC.merge(Deseq2_pDC_72, on='Gene', how='outer')

merged_df_PF = Deseq2_PF_2.merge(Deseq2_PF_4, on='Gene', how='outer')
merged_df_PF = merged_df_PF.merge(Deseq2_PF_8, on='Gene', how='outer')
merged_df_PF = merged_df_PF.merge(Deseq2_PF_12, on='Gene', how='outer')
merged_df_PF = merged_df_PF.merge(Deseq2_PF_18, on='Gene', how='outer')
merged_df_PF = merged_df_PF.merge(Deseq2_PF_24, on='Gene', how='outer')
merged_df_PF = merged_df_PF.merge(Deseq2_PF_72, on='Gene', how='outer')

merged_df_T_Cell = Deseq2_T_Cell_2.merge(Deseq2_T_Cell_4, on='Gene', how='outer')
merged_df_T_Cell = merged_df_T_Cell.merge(Deseq2_T_Cell_8, on='Gene', how='outer')
merged_df_T_Cell = merged_df_T_Cell.merge(Deseq2_T_Cell_12, on='Gene', how='outer')
merged_df_T_Cell = merged_df_T_Cell.merge(Deseq2_T_Cell_18, on='Gene', how='outer')
merged_df_T_Cell = merged_df_T_Cell.merge(Deseq2_T_Cell_24, on='Gene', how='outer')
merged_df_T_Cell = merged_df_T_Cell.merge(Deseq2_T_Cell_72, on='Gene', how='outer')

# %%
merged_df_EC
# Out:
#           Gene    baseMean_2  log2FoldChange_2   lfcSE_2  FoldChange_2
# 0      Gm42418  79045.971262          0.035469  0.446596      1.024890  \
# 1       Malat1  36389.554717         -0.215559  0.153135      0.861213
# 2        Cmss1  13493.877814          0.353855  0.438358      1.277971
# 3        Stab2   8330.779031         -0.263018  0.244195      0.833343
# 4        Lrmda   7049.195378          0.032411  0.183423      1.022720
# ...        ...           ...               ...       ...           ...
# 13421    Ncam1      2.355809         -2.832430  1.509702      0.140396
# 13422   Pappa2      2.438074         -0.690744  1.387386      0.619534
# 13423  Rptoros      2.308974          1.078931  0.972116      2.112470
# 13424    Tbx15      2.632198          1.216791  1.000499      2.324292
# 13425   Trim45      2.308428         -0.289819  0.896066      0.818005
#
#          padj_2    baseMean_4  log2FoldChange_4   lfcSE_4  FoldChange_4  ...
# ...

# %%
merged_df_B_Cell.to_csv('./Results/Deseq2_B_Cell_Merged.txt', sep='\t')
merged_df_Cholangiocyte.to_csv('./Results/Deseq2_Cholangiocyte_Merged.txt', sep='\t')
merged_df_EC.to_csv('./Results/Deseq2_EC_Merged.txt', sep='\t')
merged_df_Hepatocyte.to_csv('./Results/Deseq2_Hepatocyte_Merged.txt', sep='\t')
merged_df_HSC.to_csv('./Results/Deseq2_HSC_Merged.txt', sep='\t')
merged_df_Macrophage.to_csv('./Results/Deseq2_Macrophage_Merged.txt', sep='\t')
merged_df_Neutrophil.to_csv('./Results/Deseq2_Neutrophil_Merged.txt', sep='\t')
merged_df_pDC.to_csv('./Results/Deseq2_pDC_Merged.txt', sep='\t')
merged_df_PF.to_csv('./Results/Deseq2_PFl_Merged.txt', sep='\t')
merged_df_T_Cell.to_csv('./Results/Deseq2_T_Cell_Merged.txt', sep='\t')

# %%
merged_df_pDC
# Out:
#          Gene  baseMean_2  log2FoldChange_2   lfcSE_2  FoldChange_2  padj_2
# 0     Gm42418  786.217400          0.085839  0.625698      1.061304       1  \
# 1      Malat1  342.282446         -0.483277  0.352650      0.715351       1
# 2       Cmss1  130.404363          0.404770  0.539862      1.323878       1
# 3        Tcf4   92.688756          0.110635  0.382994      1.079704       1
# 4      Camk1d   59.078650          0.151232  0.473733      1.110518       1
# ...       ...         ...               ...       ...           ...     ...
# 3044    Ube2i    1.098257          0.279049  1.453321      1.213395       1
# 3045      Unk    1.015365          0.544660  1.781050      1.458677       1
# 3046    Usp10    0.918732          2.267873  1.894032      4.816126       1
# 3047   Washc2    1.179280          1.914063  1.695774      3.768690       1
# 3048     Wwc2    0.983213         -0.571593  1.619675      0.672874       1
#
# ...
